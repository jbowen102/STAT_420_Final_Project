# %%
PROJECT_DIR = getwd()

# %%
source("feature_construction.R")
# Out:
# [1] "Reading in elevation-data buffer"
# [1] "Reading in distance-to-coast data"
# [1] "Reading in MRLC land-cover raster"
# [1] "Reading in PRISM Tmean raster"
# [1] "Reading in PRISM precip raster"

# %% [markdown]
# ### Create feature df

# %%
ebird_features_df_pwo <- construct_feature_df("pileated_woodpecker_20251130.txt")
df_out_file <- "features--pile_woodp_2024_us-sc.csv"
save_feature_df(ebird_features_df_pwo, df_out_file)

# %% [markdown]
# ---

# %%
ebird_features_df_osp <- construct_feature_df("osprey_20251130.txt")
df_out_file <- "features--osprey_2024_us-sc.csv"
save_feature_df(ebird_features_df_osp, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_gho <- construct_feature_df("great_horned_owl_20251130.txt")
df_out_file <- "features--great_h_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_gho, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_rth <- construct_feature_df("red-tailed_hawk_20251201.txt")
df_out_file <- "features--red_t_hawk_2024_us-sc.csv"
save_feature_df(ebird_features_df_rth, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_sho <- construct_feature_df("short-eared_owl_20251130.txt")
df_out_file <- "features--short_e_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_sho, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_cha <- construct_feature_df("coopers_hawk_20251201.txt")
df_out_file <- "features--coopers_hawk_2024_us-sc.csv"
save_feature_df(ebird_features_df_cha, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_abo <- construct_feature_df("american_barn_owl_20251201.txt")
df_out_file <- "features--a_barn_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_abo, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_bow <- construct_feature_df("barred_owl_20251201.txt")
df_out_file <- "features--barred_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_bow, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_rhw <- construct_feature_df("red-headed_woodpecker_20251201.txt")
df_out_file <- "features--red_h_woodp_2024_us-sc.csv"
save_feature_df(ebird_features_df_rhw, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %% [markdown]
# ### Read feature df in

# %%
ebird_features_df_pwo <- read_feature_df("features--pile_woodp_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_osp <- read_feature_df("features--osprey_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_gho <- read_feature_df("features--great_h_owl_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_rth <- read_feature_df("features--red_t_hawk_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_sho <- read_feature_df("features--short_e_owl_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_cha <- read_feature_df("features--coopers_hawk_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_abo <- read_feature_df("features--a_barn_owl_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_bow <- read_feature_df("features--barred_owl_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_rhw <- read_feature_df("features--red_h_woodp_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ### model exp 1

# %%
ebird_features_df_pwo

# %%
ebird_features_df_osp

# %%
# pairs(ebird_features_df_pwo[c("mean_num_observers", "mean_start_time_hr", "med_duration", "mean_dist_km",
#         "dist_to_coast_mi", "elevation_ft", "Forest", "dominant_eco_group",
#         "tmean_2024_C", "ppt_2024_mm", "det_freq")])
pairs(ebird_features_df_pwo[c(
        "dist_to_coast_mi", "elevation_ft", "Forest", "dominant_eco_group",
        "tmean_2024_C", "ppt_2024_mm", "det_freq")])
# Out:
# plot without title

# %%
# pairs(ebird_features_df_osp[c("mean_num_observers", "mean_start_time_hr", "med_duration", "mean_dist_km",
#         "dist_to_coast_mi", "elevation_ft", "Forest", "Water", "dominant_eco_group",
#         "tmean_2024_C", "ppt_2024_mm", "det_freq")])
pairs(ebird_features_df_osp[c(
        "dist_to_coast_mi", "elevation_ft", "Forest", "Water", "dominant_eco_group",
        "tmean_2024_C", "ppt_2024_mm", "det_freq")])
# Out:
# plot without title

# %%
mod_add_pwo = lm(det_freq ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + Forest + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm,
                data = ebird_features_df_pwo, weight = n_checklists)

summary(mod_add_pwo)
# Out:
# Call:
# lm(formula = det_freq ~ mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     Forest + dominant_eco_group + tmean_2024_C + ppt_2024_mm,
#     data = ebird_features_df_pwo, weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -5.8407 -0.3335 -0.0764  0.3724  5.7139
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  3.236e-02  1.860e-01   0.174 0.861894
# mean_num_observers          -2.248e-02  2.376e-02  -0.946 0.344357
# mean_start_time_hr          -1.205e-02  3.603e-03  -3.344 0.000869 ***
# med_duration                 1.192e-01  1.301e-02   9.168  < 2e-16 ***
# mean_dist_km                 8.073e-02  7.505e-03  10.758  < 2e-16 ***
# dist_to_coast_mi             2.167e-04  1.508e-04   1.437 0.151238
# elevation_ft                -2.603e-05  2.862e-05  -0.909 0.363427
# Forest                       3.525e-01  4.359e-02   8.087 2.68e-15 ***
# dominant_eco_groupDeveloped -6.223e-02  2.510e-02  -2.480 0.013378 *
# dominant_eco_groupForest    -1.090e-01  2.759e-02  -3.951 8.56e-05 ***
# dominant_eco_groupWater     -6.087e-02  2.735e-02  -2.226 0.026329 *
# dominant_eco_groupWetland    1.863e-02  2.645e-02   0.704 0.481410
# tmean_2024_C                 4.055e-03  9.325e-03   0.435 0.663808
# ppt_2024_mm                 -5.005e-06  3.166e-05  -0.158 0.874427
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8566 on 703 degrees of freedom
# Multiple R-squared:  0.497,	Adjusted R-squared:  0.4877
# F-statistic: 53.44 on 13 and 703 DF,  p-value: < 2.2e-16

# %%
mod_add_osp = lm(det_freq ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + Forest + Water + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm,
                data = ebird_features_df_osp, weight = n_checklists)

summary(mod_add_osp)
# Out:
# Call:
# lm(formula = det_freq ~ mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     Forest + Water + dominant_eco_group + tmean_2024_C + ppt_2024_mm,
#     data = ebird_features_df_osp, weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -3.5024 -0.2711 -0.0859  0.0221  5.1562
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -3.112e-01  1.549e-01  -2.009  0.04490 *
# mean_num_observers           1.528e-02  1.981e-02   0.771  0.44085
# mean_start_time_hr          -4.428e-03  3.032e-03  -1.460  0.14467
# med_duration                 2.691e-02  1.095e-02   2.458  0.01421 *
# mean_dist_km                 2.903e-02  6.239e-03   4.653 3.91e-06 ***
# dist_to_coast_mi            -4.933e-05  1.258e-04  -0.392  0.69501
# elevation_ft                -5.555e-05  2.407e-05  -2.308  0.02130 *
# Forest                       3.077e-02  3.734e-02   0.824  0.41026
# Water                        4.634e-01  4.031e-02  11.497  < 2e-16 ***
# dominant_eco_groupDeveloped  2.143e-02  2.086e-02   1.027  0.30471
# dominant_eco_groupForest     4.146e-02  2.326e-02   1.783  0.07504 .
# dominant_eco_groupWater     -4.557e-02  2.831e-02  -1.610  0.10791
# dominant_eco_groupWetland    1.669e-02  2.214e-02   0.754  0.45124
# tmean_2024_C                 1.336e-02  7.819e-03   1.708  0.08803 .
# ppt_2024_mm                  6.836e-05  2.634e-05   2.595  0.00964 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.712 on 702 degrees of freedom
# Multiple R-squared:  0.5187,	Adjusted R-squared:  0.5091
# F-statistic: 54.03 on 14 and 702 DF,  p-value: < 2.2e-16

# %%
mod_int_pwo = lm(det_freq ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                         dist_to_coast_mi + elevation_ft + Forest + dominant_eco_group +
                         tmean_2024_C + ppt_2024_mm)^2,
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_int_pwo)
# Out:
# Call:
# lm(formula = det_freq ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     Forest + dominant_eco_group + tmean_2024_C + ppt_2024_mm)^2,
#     data = ebird_features_df_pwo, weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -2.9986 -0.3410 -0.0954  0.3242  3.2943
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                    -1.471e+00  3.151e+00  -0.467
# mean_num_observers                             -1.302e+00  9.509e-01  -1.370
# mean_start_time_hr                              1.411e-02  1.771e-01   0.080
# med_duration                                   -4.873e-01  6.726e-01  -0.725
# mean_dist_km                                    1.610e+00  3.234e-01   4.978
# dist_to_coast_mi                                9.831e-03  6.377e-03   1.542
# elevation_ft                                   -3.128e-04  1.311e-03  -0.238
# Forest                                         -5.983e+00  2.228e+00  -2.685
# dominant_eco_groupDeveloped                     1.788e+00  1.472e+00   1.214
# dominant_eco_groupForest                        2.544e+00  1.642e+00   1.549
# dominant_eco_groupWater                         6.531e-01  1.648e+00   0.396
# dominant_eco_groupWetland                       2.837e+00  1.502e+00   1.888
# tmean_2024_C                                    1.152e-01  1.599e-01   0.720
# ppt_2024_mm                                    -5.693e-05  1.473e-03  -0.039
# mean_num_observers:mean_start_time_hr           3.476e-02  1.497e-02   2.323
# mean_num_observers:med_duration                 2.993e-02  5.817e-02   0.515
# mean_num_observers:mean_dist_km                -3.573e-02  2.875e-02  -1.243
# mean_num_observers:dist_to_coast_mi             8.229e-04  9.558e-04   0.861
# mean_num_observers:elevation_ft                 3.839e-05  1.496e-04   0.257
# mean_num_observers:Forest                       6.290e-02  2.124e-01   0.296
# mean_num_observers:dominant_eco_groupDeveloped -1.083e-01  1.337e-01  -0.810
# mean_num_observers:dominant_eco_groupForest     1.382e-01  1.397e-01   0.989
# mean_num_observers:dominant_eco_groupWater      1.228e-02  1.584e-01   0.078
# mean_num_observers:dominant_eco_groupWetland    1.334e-01  1.269e-01   1.051
# mean_num_observers:tmean_2024_C                 4.494e-02  4.894e-02   0.918
# mean_num_observers:ppt_2024_mm                 -8.518e-05  1.896e-04  -0.449
# mean_start_time_hr:med_duration                -1.159e-02  9.883e-03  -1.173
# mean_start_time_hr:mean_dist_km                -2.038e-02  5.132e-03  -3.971
# mean_start_time_hr:dist_to_coast_mi            -3.148e-04  2.046e-04  -1.538
# mean_start_time_hr:elevation_ft                -6.921e-06  3.012e-05  -0.230
# mean_start_time_hr:Forest                       5.900e-02  3.953e-02   1.493
# mean_start_time_hr:dominant_eco_groupDeveloped -1.727e-03  2.065e-02  -0.084
# mean_start_time_hr:dominant_eco_groupForest    -1.018e-02  2.218e-02  -0.459
# mean_start_time_hr:dominant_eco_groupWater     -1.345e-02  2.375e-02  -0.566
# mean_start_time_hr:dominant_eco_groupWetland   -4.935e-02  2.092e-02  -2.359
# mean_start_time_hr:tmean_2024_C                -1.848e-03  9.332e-03  -0.198
# mean_start_time_hr:ppt_2024_mm                  1.342e-05  2.796e-05   0.480
# med_duration:mean_dist_km                      -2.499e-03  1.785e-02  -0.140
# med_duration:dist_to_coast_mi                   1.005e-04  6.078e-04   0.165
# med_duration:elevation_ft                       1.262e-04  1.183e-04   1.066
# med_duration:Forest                             7.520e-02  1.303e-01   0.577
# med_duration:dominant_eco_groupDeveloped       -2.116e-01  9.764e-02  -2.167
# med_duration:dominant_eco_groupForest          -1.840e-01  9.713e-02  -1.894
# med_duration:dominant_eco_groupWater           -7.009e-02  1.208e-01  -0.580
# med_duration:dominant_eco_groupWetland         -4.148e-02  9.861e-02  -0.421
# med_duration:tmean_2024_C                       3.039e-02  3.492e-02   0.870
# med_duration:ppt_2024_mm                        1.438e-04  1.179e-04   1.219
# mean_dist_km:dist_to_coast_mi                   2.613e-04  3.934e-04   0.664
# mean_dist_km:elevation_ft                      -2.796e-04  7.642e-05  -3.659
# mean_dist_km:Forest                             5.700e-02  8.268e-02   0.689
# mean_dist_km:dominant_eco_groupDeveloped        1.821e-01  3.125e-02   5.826
# mean_dist_km:dominant_eco_groupForest           1.111e-01  3.613e-02   3.075
# mean_dist_km:dominant_eco_groupWater            2.247e-01  5.961e-02   3.769
# mean_dist_km:dominant_eco_groupWetland          1.401e-01  3.365e-02   4.164
# mean_dist_km:tmean_2024_C                      -7.908e-02  1.695e-02  -4.665
# mean_dist_km:ppt_2024_mm                        6.136e-05  6.362e-05   0.964
# dist_to_coast_mi:elevation_ft                  -3.528e-07  8.579e-07  -0.411
# dist_to_coast_mi:Forest                         2.953e-03  2.279e-03   1.296
# dist_to_coast_mi:dominant_eco_groupDeveloped    2.129e-03  1.788e-03   1.191
# dist_to_coast_mi:dominant_eco_groupForest      -2.043e-04  1.885e-03  -0.108
# dist_to_coast_mi:dominant_eco_groupWater        2.276e-03  2.374e-03   0.959
# dist_to_coast_mi:dominant_eco_groupWetland      3.044e-03  1.894e-03   1.607
# dist_to_coast_mi:tmean_2024_C                  -5.911e-04  2.775e-04  -2.130
# dist_to_coast_mi:ppt_2024_mm                    1.380e-06  1.207e-06   1.143
# elevation_ft:Forest                             9.570e-04  3.456e-04   2.769
# elevation_ft:dominant_eco_groupDeveloped       -3.461e-04  3.191e-04  -1.084
# elevation_ft:dominant_eco_groupForest          -4.652e-04  3.415e-04  -1.362
# elevation_ft:dominant_eco_groupWater           -4.846e-04  4.877e-04  -0.994
# elevation_ft:dominant_eco_groupWetland         -2.126e-04  5.320e-04  -0.400
# elevation_ft:tmean_2024_C                       3.485e-05  5.551e-05   0.628
# elevation_ft:ppt_2024_mm                       -5.531e-08  1.804e-07  -0.307
# Forest:dominant_eco_groupDeveloped             -3.176e-01  3.913e-01  -0.812
# Forest:dominant_eco_groupForest                -2.052e-01  3.854e-01  -0.532
# Forest:dominant_eco_groupWater                  1.154e+00  5.450e-01   2.118
# Forest:dominant_eco_groupWetland               -2.957e-02  4.108e-01  -0.072
# Forest:tmean_2024_C                             2.963e-01  1.080e-01   2.744
# Forest:ppt_2024_mm                             -3.696e-04  3.341e-04  -1.106
# dominant_eco_groupDeveloped:tmean_2024_C       -8.086e-02  6.723e-02  -1.203
# dominant_eco_groupForest:tmean_2024_C          -1.265e-01  7.668e-02  -1.650
# dominant_eco_groupWater:tmean_2024_C           -6.322e-02  7.491e-02  -0.844
# dominant_eco_groupWetland:tmean_2024_C         -1.527e-01  6.953e-02  -2.196
# dominant_eco_groupDeveloped:ppt_2024_mm        -2.409e-04  2.675e-04  -0.901
# dominant_eco_groupForest:ppt_2024_mm           -6.479e-05  2.884e-04  -0.225
# dominant_eco_groupWater:ppt_2024_mm             1.339e-04  3.398e-04   0.394
# dominant_eco_groupWetland:ppt_2024_mm           1.389e-04  2.725e-04   0.510
# tmean_2024_C:ppt_2024_mm                       -5.279e-06  6.930e-05  -0.076
#                                                Pr(>|t|)
# (Intercept)                                    0.640684
# mean_num_observers                             0.171237
# mean_start_time_hr                             0.936517
# med_duration                                   0.468982
# mean_dist_km                                   8.28e-07 ***
# dist_to_coast_mi                               0.123632
# elevation_ft                                   0.811574
# Forest                                         0.007438 **
# dominant_eco_groupDeveloped                    0.225161
# dominant_eco_groupForest                       0.121873
# dominant_eco_groupWater                        0.692052
# dominant_eco_groupWetland                      0.059471 .
# tmean_2024_C                                   0.471725
# ppt_2024_mm                                    0.969188
# mean_num_observers:mean_start_time_hr          0.020510 *
# mean_num_observers:med_duration                0.607066
# mean_num_observers:mean_dist_km                0.214483
# mean_num_observers:dist_to_coast_mi            0.389589
# mean_num_observers:elevation_ft                0.797543
# mean_num_observers:Forest                      0.767244
# mean_num_observers:dominant_eco_groupDeveloped 0.418139
# mean_num_observers:dominant_eco_groupForest    0.322949
# mean_num_observers:dominant_eco_groupWater     0.938220
# mean_num_observers:dominant_eco_groupWetland   0.293554
# mean_num_observers:tmean_2024_C                0.358839
# mean_num_observers:ppt_2024_mm                 0.653426
# mean_start_time_hr:med_duration                0.241265
# mean_start_time_hr:mean_dist_km                7.99e-05 ***
# mean_start_time_hr:dist_to_coast_mi            0.124524
# mean_start_time_hr:elevation_ft                0.818354
# mean_start_time_hr:Forest                      0.135982
# mean_start_time_hr:dominant_eco_groupDeveloped 0.933382
# mean_start_time_hr:dominant_eco_groupForest    0.646278
# mean_start_time_hr:dominant_eco_groupWater     0.571402
# mean_start_time_hr:dominant_eco_groupWetland   0.018612 *
# mean_start_time_hr:tmean_2024_C                0.843107
# mean_start_time_hr:ppt_2024_mm                 0.631279
# med_duration:mean_dist_km                      0.888727
# med_duration:dist_to_coast_mi                  0.868665
# med_duration:elevation_ft                      0.286747
# med_duration:Forest                            0.564167
# med_duration:dominant_eco_groupDeveloped       0.030587 *
# med_duration:dominant_eco_groupForest          0.058627 .
# med_duration:dominant_eco_groupWater           0.561932
# med_duration:dominant_eco_groupWetland         0.674177
# med_duration:tmean_2024_C                      0.384511
# med_duration:ppt_2024_mm                       0.223230
# mean_dist_km:dist_to_coast_mi                  0.506787
# mean_dist_km:elevation_ft                      0.000275 ***
# mean_dist_km:Forest                            0.490862
# mean_dist_km:dominant_eco_groupDeveloped       9.04e-09 ***
# mean_dist_km:dominant_eco_groupForest          0.002197 **
# mean_dist_km:dominant_eco_groupWater           0.000179 ***
# mean_dist_km:dominant_eco_groupWetland         3.57e-05 ***
# mean_dist_km:tmean_2024_C                      3.77e-06 ***
# mean_dist_km:ppt_2024_mm                       0.335167
# dist_to_coast_mi:elevation_ft                  0.681074
# dist_to_coast_mi:Forest                        0.195509
# dist_to_coast_mi:dominant_eco_groupDeveloped   0.234117
# dist_to_coast_mi:dominant_eco_groupForest      0.913719
# dist_to_coast_mi:dominant_eco_groupWater       0.337968
# dist_to_coast_mi:dominant_eco_groupWetland     0.108549
# dist_to_coast_mi:tmean_2024_C                  0.033557 *
# dist_to_coast_mi:ppt_2024_mm                   0.253328
# elevation_ft:Forest                            0.005790 **
# elevation_ft:dominant_eco_groupDeveloped       0.278578
# elevation_ft:dominant_eco_groupForest          0.173535
# elevation_ft:dominant_eco_groupWater           0.320832
# elevation_ft:dominant_eco_groupWetland         0.689502
# elevation_ft:tmean_2024_C                      0.530294
# elevation_ft:ppt_2024_mm                       0.759288
# Forest:dominant_eco_groupDeveloped             0.417254
# Forest:dominant_eco_groupForest                0.594685
# Forest:dominant_eco_groupWater                 0.034566 *
# Forest:dominant_eco_groupWetland               0.942646
# Forest:tmean_2024_C                            0.006244 **
# Forest:ppt_2024_mm                             0.269104
# dominant_eco_groupDeveloped:tmean_2024_C       0.229525
# dominant_eco_groupForest:tmean_2024_C          0.099522 .
# dominant_eco_groupWater:tmean_2024_C           0.398977
# dominant_eco_groupWetland:tmean_2024_C         0.028426 *
# dominant_eco_groupDeveloped:ppt_2024_mm        0.368175
# dominant_eco_groupForest:ppt_2024_mm           0.822322
# dominant_eco_groupWater:ppt_2024_mm            0.693583
# dominant_eco_groupWetland:ppt_2024_mm          0.610337
# tmean_2024_C:ppt_2024_mm                       0.939301
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6865 on 631 degrees of freedom
# Multiple R-squared:   0.71,	Adjusted R-squared:  0.6709
# F-statistic: 18.17 on 85 and 631 DF,  p-value: < 2.2e-16

# %%
mod_int_osp = lm(det_freq ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                         dist_to_coast_mi + elevation_ft + Forest + Water + dominant_eco_group +
                         tmean_2024_C + ppt_2024_mm)^2,
                data = ebird_features_df_osp, weight = n_checklists)
summary(mod_int_osp)
# Out:
# Call:
# lm(formula = det_freq ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     Forest + Water + dominant_eco_group + tmean_2024_C + ppt_2024_mm)^2,
#     data = ebird_features_df_osp, weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8957 -0.2123 -0.0550  0.0971  3.2426
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                     3.103e+00  2.737e+00   1.134
# mean_num_observers                             -1.263e-01  8.551e-01  -0.148
# mean_start_time_hr                              6.418e-02  1.556e-01   0.413
# med_duration                                   -1.684e+00  5.674e-01  -2.968
# mean_dist_km                                   -5.876e-01  2.879e-01  -2.041
# dist_to_coast_mi                               -6.047e-03  5.440e-03  -1.112
# elevation_ft                                   -1.282e-03  1.081e-03  -1.186
# Forest                                         -1.496e-01  1.864e+00  -0.080
# Water                                           4.330e+00  2.097e+00   2.065
# dominant_eco_groupDeveloped                    -7.647e-01  1.212e+00  -0.631
# dominant_eco_groupForest                       -4.655e-01  1.350e+00  -0.345
# dominant_eco_groupWater                        -6.411e+00  1.874e+00  -3.421
# dominant_eco_groupWetland                      -1.231e+00  1.245e+00  -0.989
# tmean_2024_C                                   -2.083e-01  1.400e-01  -1.488
# ppt_2024_mm                                     3.118e-04  1.226e-03   0.254
# mean_num_observers:mean_start_time_hr           1.448e-02  1.241e-02   1.168
# mean_num_observers:med_duration                 2.365e-02  4.876e-02   0.485
# mean_num_observers:mean_dist_km                -2.556e-02  2.413e-02  -1.059
# mean_num_observers:dist_to_coast_mi            -1.160e-03  8.083e-04  -1.435
# mean_num_observers:elevation_ft                 2.394e-04  1.228e-04   1.949
# mean_num_observers:Forest                      -1.823e-01  1.759e-01  -1.036
# mean_num_observers:Water                       -2.972e-01  2.128e-01  -1.397
# mean_num_observers:dominant_eco_groupDeveloped -8.294e-03  1.137e-01  -0.073
# mean_num_observers:dominant_eco_groupForest     1.557e-01  1.177e-01   1.323
# mean_num_observers:dominant_eco_groupWater      3.121e-01  1.765e-01   1.768
# mean_num_observers:dominant_eco_groupWetland    8.625e-02  1.080e-01   0.799
# mean_num_observers:tmean_2024_C                 8.082e-03  4.359e-02   0.185
# mean_num_observers:ppt_2024_mm                 -1.202e-04  1.573e-04  -0.764
# mean_start_time_hr:med_duration                -1.683e-04  8.076e-03  -0.021
# mean_start_time_hr:mean_dist_km                -5.471e-03  4.220e-03  -1.296
# mean_start_time_hr:dist_to_coast_mi            -1.759e-05  1.761e-04  -0.100
# mean_start_time_hr:elevation_ft                -3.696e-06  2.513e-05  -0.147
# mean_start_time_hr:Forest                       4.555e-02  3.346e-02   1.361
# mean_start_time_hr:Water                       -8.899e-03  5.569e-02  -0.160
# mean_start_time_hr:dominant_eco_groupDeveloped -5.902e-03  1.755e-02  -0.336
# mean_start_time_hr:dominant_eco_groupForest    -2.070e-02  1.906e-02  -1.086
# mean_start_time_hr:dominant_eco_groupWater      7.124e-03  3.466e-02   0.206
# mean_start_time_hr:dominant_eco_groupWetland   -2.452e-02  1.794e-02  -1.367
# mean_start_time_hr:tmean_2024_C                -1.276e-03  8.192e-03  -0.156
# mean_start_time_hr:ppt_2024_mm                 -3.583e-05  2.288e-05  -1.566
# med_duration:mean_dist_km                       1.774e-02  1.460e-02   1.215
# med_duration:dist_to_coast_mi                   1.065e-03  5.036e-04   2.115
# med_duration:elevation_ft                      -1.003e-04  9.881e-05  -1.015
# med_duration:Forest                             1.176e-01  1.107e-01   1.062
# med_duration:Water                              1.493e-01  2.069e-01   0.722
# med_duration:dominant_eco_groupDeveloped        1.911e-02  8.071e-02   0.237
# med_duration:dominant_eco_groupForest          -3.955e-03  8.005e-02  -0.049
# med_duration:dominant_eco_groupWater            1.945e-01  1.516e-01   1.283
# med_duration:dominant_eco_groupWetland         -2.225e-02  8.115e-02  -0.274
# med_duration:tmean_2024_C                       6.941e-02  2.949e-02   2.354
# med_duration:ppt_2024_mm                        2.220e-04  9.761e-05   2.274
# mean_dist_km:dist_to_coast_mi                   2.333e-04  3.406e-04   0.685
# mean_dist_km:elevation_ft                       5.225e-05  6.325e-05   0.826
# mean_dist_km:Forest                             3.288e-02  7.028e-02   0.468
# mean_dist_km:Water                             -2.964e-01  1.081e-01  -2.743
# mean_dist_km:dominant_eco_groupDeveloped       -1.430e-02  2.613e-02  -0.547
# mean_dist_km:dominant_eco_groupForest          -4.009e-03  3.038e-02  -0.132
# mean_dist_km:dominant_eco_groupWater            2.358e-01  7.323e-02   3.219
# mean_dist_km:dominant_eco_groupWetland          2.670e-02  2.789e-02   0.957
# mean_dist_km:tmean_2024_C                       3.558e-02  1.514e-02   2.351
# mean_dist_km:ppt_2024_mm                       -1.386e-05  5.455e-05  -0.254
# dist_to_coast_mi:elevation_ft                   1.818e-06  7.147e-07   2.544
# dist_to_coast_mi:Forest                        -6.331e-03  1.922e-03  -3.294
# dist_to_coast_mi:Water                          2.185e-02  4.021e-03   5.434
# dist_to_coast_mi:dominant_eco_groupDeveloped   -3.093e-04  1.525e-03  -0.203
# dist_to_coast_mi:dominant_eco_groupForest       1.961e-03  1.613e-03   1.216
# dist_to_coast_mi:dominant_eco_groupWater       -5.713e-03  2.654e-03  -2.153
# dist_to_coast_mi:dominant_eco_groupWetland     -1.858e-03  1.601e-03  -1.161
# dist_to_coast_mi:tmean_2024_C                   3.679e-04  2.353e-04   1.564
# dist_to_coast_mi:ppt_2024_mm                    6.113e-08  1.058e-06   0.058
# elevation_ft:Forest                             5.446e-04  2.895e-04   1.881
# elevation_ft:Water                             -5.868e-03  8.031e-04  -7.307
# elevation_ft:dominant_eco_groupDeveloped        1.361e-04  2.595e-04   0.525
# elevation_ft:dominant_eco_groupForest          -9.078e-05  2.798e-04  -0.324
# elevation_ft:dominant_eco_groupWater            1.979e-03  5.110e-04   3.873
# elevation_ft:dominant_eco_groupWetland          8.736e-04  4.352e-04   2.007
# elevation_ft:tmean_2024_C                       3.957e-05  4.603e-05   0.860
# elevation_ft:ppt_2024_mm                       -6.433e-08  1.482e-07  -0.434
# Forest:Water                                   -1.689e+00  6.845e-01  -2.468
# Forest:dominant_eco_groupDeveloped              1.813e-01  3.606e-01   0.503
# Forest:dominant_eco_groupForest                 1.817e-01  3.594e-01   0.506
# Forest:dominant_eco_groupWater                  1.139e+00  5.691e-01   2.001
# Forest:dominant_eco_groupWetland               -3.485e-01  3.726e-01  -0.935
# Forest:tmean_2024_C                             6.435e-03  9.079e-02   0.071
# Forest:ppt_2024_mm                              4.981e-05  2.823e-04   0.176
# Water:dominant_eco_groupDeveloped               9.886e-01  4.921e-01   2.009
# Water:dominant_eco_groupForest                  1.203e+00  4.859e-01   2.476
# Water:dominant_eco_groupWater                   1.295e-01  5.018e-01   0.258
# Water:dominant_eco_groupWetland                 4.090e-01  5.150e-01   0.794
# Water:tmean_2024_C                             -2.196e-01  1.089e-01  -2.016
# Water:ppt_2024_mm                               6.117e-04  4.122e-04   1.484
# dominant_eco_groupDeveloped:tmean_2024_C        4.582e-02  5.812e-02   0.788
# dominant_eco_groupForest:tmean_2024_C           3.206e-02  6.515e-02   0.492
# dominant_eco_groupWater:tmean_2024_C            2.439e-01  9.011e-02   2.706
# dominant_eco_groupWetland:tmean_2024_C          1.067e-01  6.037e-02   1.767
# dominant_eco_groupDeveloped:ppt_2024_mm        -5.888e-05  2.232e-04  -0.264
# dominant_eco_groupForest:ppt_2024_mm           -2.239e-04  2.419e-04  -0.925
# dominant_eco_groupWater:ppt_2024_mm             5.750e-04  3.143e-04   1.830
# dominant_eco_groupWetland:ppt_2024_mm          -4.170e-04  2.274e-04  -1.834
# tmean_2024_C:ppt_2024_mm                        2.185e-05  5.767e-05   0.379
#                                                Pr(>|t|)
# (Intercept)                                    0.257324
# mean_num_observers                             0.882662
# mean_start_time_hr                             0.680050
# med_duration                                   0.003114 **
# mean_dist_km                                   0.041671 *
# dist_to_coast_mi                               0.266769
# elevation_ft                                   0.236093
# Forest                                         0.936049
# Water                                          0.039337 *
# dominant_eco_groupDeveloped                    0.528124
# dominant_eco_groupForest                       0.730258
# dominant_eco_groupWater                        0.000666 ***
# dominant_eco_groupWetland                      0.323028
# tmean_2024_C                                   0.137250
# ppt_2024_mm                                    0.799414
# mean_num_observers:mean_start_time_hr          0.243411
# mean_num_observers:med_duration                0.627836
# mean_num_observers:mean_dist_km                0.290047
# mean_num_observers:dist_to_coast_mi            0.151707
# mean_num_observers:elevation_ft                0.051747 .
# mean_num_observers:Forest                      0.300463
# mean_num_observers:Water                       0.162901
# mean_num_observers:dominant_eco_groupDeveloped 0.941875
# mean_num_observers:dominant_eco_groupForest    0.186322
# mean_num_observers:dominant_eco_groupWater     0.077580 .
# mean_num_observers:dominant_eco_groupWetland   0.424827
# mean_num_observers:tmean_2024_C                0.852970
# mean_num_observers:ppt_2024_mm                 0.445060
# mean_start_time_hr:med_duration                0.983384
# mean_start_time_hr:mean_dist_km                0.195307
# mean_start_time_hr:dist_to_coast_mi            0.920484
# mean_start_time_hr:elevation_ft                0.883101
# mean_start_time_hr:Forest                      0.173966
# mean_start_time_hr:Water                       0.873095
# mean_start_time_hr:dominant_eco_groupDeveloped 0.736694
# mean_start_time_hr:dominant_eco_groupForest    0.277747
# mean_start_time_hr:dominant_eco_groupWater     0.837235
# mean_start_time_hr:dominant_eco_groupWetland   0.172271
# mean_start_time_hr:tmean_2024_C                0.876219
# mean_start_time_hr:ppt_2024_mm                 0.117969
# med_duration:mean_dist_km                      0.224811
# med_duration:dist_to_coast_mi                  0.034868 *
# med_duration:elevation_ft                      0.310482
# med_duration:Forest                            0.288530
# med_duration:Water                             0.470788
# med_duration:dominant_eco_groupDeveloped       0.812901
# med_duration:dominant_eco_groupForest          0.960611
# med_duration:dominant_eco_groupWater           0.200011
# med_duration:dominant_eco_groupWetland         0.784015
# med_duration:tmean_2024_C                      0.018909 *
# med_duration:ppt_2024_mm                       0.023306 *
# mean_dist_km:dist_to_coast_mi                  0.493541
# mean_dist_km:elevation_ft                      0.409056
# mean_dist_km:Forest                            0.640030
# mean_dist_km:Water                             0.006273 **
# mean_dist_km:dominant_eco_groupDeveloped       0.584330
# mean_dist_km:dominant_eco_groupForest          0.895053
# mean_dist_km:dominant_eco_groupWater           0.001352 **
# mean_dist_km:dominant_eco_groupWetland         0.338711
# mean_dist_km:tmean_2024_C                      0.019057 *
# mean_dist_km:ppt_2024_mm                       0.799469
# dist_to_coast_mi:elevation_ft                  0.011193 *
# dist_to_coast_mi:Forest                        0.001043 **
# dist_to_coast_mi:Water                         7.94e-08 ***
# dist_to_coast_mi:dominant_eco_groupDeveloped   0.839305
# dist_to_coast_mi:dominant_eco_groupForest      0.224512
# dist_to_coast_mi:dominant_eco_groupWater       0.031731 *
# dist_to_coast_mi:dominant_eco_groupWetland     0.246132
# dist_to_coast_mi:tmean_2024_C                  0.118437
# dist_to_coast_mi:ppt_2024_mm                   0.953958
# elevation_ft:Forest                            0.060454 .
# elevation_ft:Water                             8.47e-13 ***
# elevation_ft:dominant_eco_groupDeveloped       0.600086
# elevation_ft:dominant_eco_groupForest          0.745680
# elevation_ft:dominant_eco_groupWater           0.000119 ***
# elevation_ft:dominant_eco_groupWetland         0.045143 *
# elevation_ft:tmean_2024_C                      0.390377
# elevation_ft:ppt_2024_mm                       0.664424
# Forest:Water                                   0.013871 *
# Forest:dominant_eco_groupDeveloped             0.615315
# Forest:dominant_eco_groupForest                0.613339
# Forest:dominant_eco_groupWater                 0.045805 *
# Forest:dominant_eco_groupWetland               0.350101
# Forest:tmean_2024_C                            0.943515
# Forest:ppt_2024_mm                             0.860004
# Water:dominant_eco_groupDeveloped              0.044981 *
# Water:dominant_eco_groupForest                 0.013551 *
# Water:dominant_eco_groupWater                  0.796495
# Water:dominant_eco_groupWetland                0.427418
# Water:tmean_2024_C                             0.044273 *
# Water:ppt_2024_mm                              0.138298
# dominant_eco_groupDeveloped:tmean_2024_C       0.430811
# dominant_eco_groupForest:tmean_2024_C          0.622835
# dominant_eco_groupWater:tmean_2024_C           0.006988 **
# dominant_eco_groupWetland:tmean_2024_C         0.077779 .
# dominant_eco_groupDeveloped:ppt_2024_mm        0.792018
# dominant_eco_groupForest:ppt_2024_mm           0.355098
# dominant_eco_groupWater:ppt_2024_mm            0.067791 .
# dominant_eco_groupWetland:ppt_2024_mm          0.067198 .
# tmean_2024_C:ppt_2024_mm                       0.704901
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5524 on 617 degrees of freedom
# Multiple R-squared:  0.7454,	Adjusted R-squared:  0.7045
# F-statistic: 18.25 on 99 and 617 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### standardizing attempt

# %%
standardized_ebird = scale(select(ebird_features_df_pwo, mean_num_observers,
    mean_start_time_hr,
    med_duration,
    mean_dist_km,
    dist_to_coast_mi,
    elevation_ft,
    Forest,
    tmean_2024_C,
    ppt_2024_mm))
ebird_features_df_pwo_std = cbind(cell = ebird_features_df_pwo$cell, standardized_ebird, dominant_eco_group = ebird_filtered_agg4$dominant_eco_group, det_freq = ebird_filtered_agg4$det_freq, n_checklists = ebird_filtered_agg4$n_checklists) %>%
    as.data.frame()
str(ebird_features_df_pwo_std)

# %%
mod_pwo_add_std = lm(det_freq ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft + Forest + dominant_eco_group + tmean_2024_C + ppt_2024_mm, data = ebird_features_df_pwo_std, weight = n_checklists)
summary(mod_pwo_add_std)
