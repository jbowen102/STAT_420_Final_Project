# %%
PROJECT_DIR = getwd()

# %%
source("feature_construction.R")
# Out:
# [1] "Reading in elevation-data buffer"
# [1] "Reading in distance-to-coast data"
# [1] "Reading in MRLC land-cover raster"
# Warning message in prism_dl_dir_check_for_v1(path):
# “The specified PRISM download directory appears to have data from the pre September 2025 API.
# We recommend either starting a new download directory for the new API and/or
# deleting and redownloading all data from the new API.”
# [1] "Reading in PRISM Tmean raster"
# [1] "Reading in PRISM precip raster"

# %% [markdown]
# ### Create feature df

# %%
ebird_features_df_pwo <- construct_feature_df("pileated_woodpecker_20251130")
df_out_file <- "features--pile_woodp_2024_us-sc.csv"
save_feature_df(ebird_features_df_pwo, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_osp <- construct_feature_df("osprey_20251130")
df_out_file <- "features--osprey_2024_us-sc.csv"
save_feature_df(ebird_features_df_osp, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %% [markdown]
# ---

# %%
ebird_features_df_gho <- construct_feature_df("great_horned_owl_20251130")
df_out_file <- "features--great_h_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_gho, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_rth <- construct_feature_df("red-tailed_hawk_20251201")
df_out_file <- "features--red_t_hawk_2024_us-sc.csv"
save_feature_df(ebird_features_df_rth, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_seo <- construct_feature_df("short-eared_owl_20251130")
df_out_file <- "features--short_e_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_seo, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_cha <- construct_feature_df("coopers_hawk_20251201")
df_out_file <- "features--coopers_hawk_2024_us-sc.csv"
save_feature_df(ebird_features_df_cha, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_abo <- construct_feature_df("american_barn_owl_20251201")
df_out_file <- "features--a_barn_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_abo, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_bow <- construct_feature_df("barred_owl_20251201")
df_out_file <- "features--barred_owl_2024_us-sc.csv"
save_feature_df(ebird_features_df_bow, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
ebird_features_df_rhw <- construct_feature_df("red-headed_woodpecker_20251201")
df_out_file <- "features--red_h_woodp_2024_us-sc.csv"
save_feature_df(ebird_features_df_rhw, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
# wood stork
ebird_features_df_wst <- construct_feature_df("wood_stork_20251202")
df_out_file <- "features--wood_stork_2024_us-sc.csv"
save_feature_df(ebird_features_df_wst, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
# brown-headed nuthatch
ebird_features_df_bhn <- construct_feature_df("brown-headed_nuthatch_20251202")
df_out_file <- "features--bh_nuthatch_2024_us-sc.csv"
save_feature_df(ebird_features_df_bhn, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %%
# turkey vulture
ebird_features_df_tvu <- construct_feature_df("turkey_vulture_20251202")
df_out_file <- "features--turkey_vulture_2024_us-sc.csv"
save_feature_df(ebird_features_df_tvu, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# ...

# %%
# swallow-tailed kit
ebird_features_df_stk <- construct_feature_df("swallow-tailed_kite_20251202")
df_out_file <- "features--swal-t_kite_2024_us-sc.csv"
save_feature_df(ebird_features_df_stk, df_out_file)
# Out:
# Resolution: 12, Area (km^2): 95.9778454662114, Spacing (km): 9.67579208698331, CLS (km): 11.0545373458563
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 15

# %% [markdown]
# ---

# %%
ebird_features_df_pwo_5km_hexes <- construct_feature_df("pileated_woodpecker_20251130", hex_spacing=5)
df_out_file <- "features--pile_woodp_2024_us-sc_5km_hexes.csv"
save_feature_df(ebird_features_df_pwo_5km_hexes, df_out_file)
# Out:
# Resolution: 13, Area (km^2): 31.9926151554038, Spacing (km): 5.58632116604266, CLS (km): 6.38233997895802
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 4

# %%
ebird_features_df_osp_5km_hexes <- construct_feature_df("osprey_20251130", hex_spacing = 5)
df_out_file <- "features--osprey_2024_us-sc_5km_hexes.csv"
save_feature_df(ebird_features_df_osp_5km_hexes, df_out_file)
# Out:
# Resolution: 13, Area (km^2): 31.9926151554038, Spacing (km): 5.58632116604266, CLS (km): 6.38233997895802
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 4

# %%
# wood stork
ebird_features_df_wst_5km_hexes <- construct_feature_df("wood_stork_20251202", hex_spacing = 5)
df_out_file <- "features--wood_stork_2024_us-sc_5km_hexes.csv"
save_feature_df(ebird_features_df_wst_5km_hexes, df_out_file)
# Out:
# Resolution: 13, Area (km^2): 31.9926151554038, Spacing (km): 5.58632116604266, CLS (km): 6.38233997895802
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 4

# %%
# brown-headed nuthatch
ebird_features_df_bhn_5km_hexes <- construct_feature_df("brown-headed_nuthatch_20251202", hex_spacing = 5)
df_out_file <- "features--bh_nuthatch_2024_us-sc_5km_hexes.csv"
save_feature_df(ebird_features_df_bhn_5km_hexes, df_out_file)
# Out:
# Resolution: 13, Area (km^2): 31.9926151554038, Spacing (km): 5.58632116604266, CLS (km): 6.38233997895802
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 4

# %%
# turkey vulture
ebird_features_df_tvu_5km_hexes <- construct_feature_df("turkey_vulture_20251202", hex_spacing = 5)
df_out_file <- "features--turkey_vulture_2024_us-sc_5km_hexes.csv"
save_feature_df(ebird_features_df_tvu_5km_hexes, df_out_file)
# Out:
# Resolution: 13, Area (km^2): 31.9926151554038, Spacing (km): 5.58632116604266, CLS (km): 6.38233997895802
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 4

# %%
# swallow-tailed kit
ebird_features_df_stk_5km_hexes <- construct_feature_df("swallow-tailed_kite_20251202", hex_spacing = 5)
df_out_file <- "features--swal-t_kite_2024_us-sc_5km_hexes.csv"
save_feature_df(ebird_features_df_stk_5km_hexes, df_out_file)
# Out:
# Resolution: 13, Area (km^2): 31.9926151554038, Spacing (km): 5.58632116604266, CLS (km): 6.38233997895802
# [1] "Adding distance-to-coast data"
# [1] "Finding dominant ecological group"
# [1] "Finding dominant land-cover class"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Adding weather covariates"
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# Warning message:
# “[extract] transforming vector data to the CRS of the raster”
# [1] "Rows w/ N/As removed:"
# [1] 4

# %%
ebird_features_df_pwo_20km_hexes <- construct_feature_df("pileated_woodpecker_20251130", hex_spacing = 20)
df_out_file <- "features--pile_woodp_2024_us-sc_20km_hexes.csv"
save_feature_df(ebird_features_df_pwo_20km_hexes, df_out_file)
# Out:
# Resolution: 11, Area (km^2): 287.933536398634, Spacing (km): 16.758963498128, CLS (km): 19.147021538141
# [1] "Adding distance-to-coast data"
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# API error, NA returned for elevation
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# API returned an empty repsonse (e.g. location in ocean or not in U.S.). NA returned for elevation
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# ...

# %%
ebird_features_df_osp_20km_hexes <- construct_feature_df("osprey_20251130", hex_spacing = 20)
df_out_file <- "features--osprey_2024_us-sc_20km_hexes.csv"
save_feature_df(ebird_features_df_osp_20km_hexes, df_out_file)
# Out:
# Resolution: 11, Area (km^2): 287.933536398634, Spacing (km): 16.758963498128, CLS (km): 19.147021538141
# [1] "Adding distance-to-coast data"
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# API returned an empty repsonse (e.g. location in ocean or not in U.S.). NA returned for elevation
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# Note: Elevation units are in feet
#
# ...
#
# ...

# %% [markdown]
# ### Read feature df in

# %%
ebird_features_df_pwo <- read_feature_df("features--pile_woodp_2024_us-sc.csv")
ebird_features_df_rhw <- read_feature_df("features--red_h_woodp_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_pwo_5km_hexes <- read_feature_df("features--pile_woodp_2024_us-sc_5km_hexes.csv")
ebird_features_df_pwo_20km_hexes <- read_feature_df("features--pile_woodp_2024_us-sc_20km_hexes.csv")
ebird_features_df_osp_5km_hexes <- read_feature_df("features--osprey_2024_us-sc_5km_hexes.csv")
ebird_features_df_osp_20km_hexes <- read_feature_df("features--osprey_2024_us-sc_20km_hexes.csv")
# Out:
# Rows: 1375 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 266 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1375 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# ...

# %%
ebird_features_df_osp <- read_feature_df("features--osprey_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ebird_features_df_rth <- read_feature_df("features--red_t_hawk_2024_us-sc.csv")
ebird_features_df_cha <- read_feature_df("features--coopers_hawk_2024_us-sc.csv")

# %%
ebird_features_df_gho <- read_feature_df("features--great_h_owl_2024_us-sc.csv")
ebird_features_df_seo <- read_feature_df("features--short_e_owl_2024_us-sc.csv")
ebird_features_df_abo <- read_feature_df("features--a_barn_owl_2024_us-sc.csv")
ebird_features_df_bow <- read_feature_df("features--barred_owl_2024_us-sc.csv")

# %%
ebird_features_df_wst <- read_feature_df("features--wood_stork_2024_us-sc.csv")
ebird_features_df_bhn <- read_feature_df("features--bh_nuthatch_2024_us-sc.csv")
ebird_features_df_tvu <- read_feature_df("features--turkey_vulture_2024_us-sc.csv")
ebird_features_df_stk <- read_feature_df("features--swal-t_kite_2024_us-sc.csv")
# Out:
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): dominant_nlcd_desc, dominant_eco_group, type
# dbl (37): cell, n_checklists, n_detected, det_freq, mean_num_observers, mean...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 717 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# ...

# %% [markdown]
# ### model exp 1

# %%
str(ebird_features_df_pwo)
# Out:
# tibble [717 × 40] (S3: tbl_df/tbl/data.frame)
#  $ cell              : num [1:717] 493475 493476 493477 493478 493479 ...
#  $ n_checklists      : int [1:717] 1 11 180 20 10 2 35 5 15 91 ...
#  $ n_detected        : int [1:717] 0 8 80 4 5 0 10 2 5 20 ...
#  $ det_freq          : num [1:717] 0 0.727 0.444 0.2 0.5 ...
#  $ mean_num_observers: num [1:717] 2 1.55 1.13 1.2 2 ...
#  $ mean_start_time_hr: num [1:717] 12.78 10.12 11.66 9.82 11.25 ...
#  $ med_duration      : num [1:717] 0.417 2.35 0.583 0.333 1.083 ...
#  $ mean_dist_km      : num [1:717] 1.043 2.238 0.392 0.408 2.41 ...
#  $ cell_ctr_lat      : num [1:717] 35.1 35.1 35.2 35.2 35.2 ...
#  $ cell_ctr_lon      : num [1:717] -82.8 -82.7 -82.5 -82.4 -82.3 ...
#  $ dist_to_coast_mi  : num [1:717] 213 211 208 206 205 ...
#  $ elevation_ft      : num [1:717] 2690 3010 2850 2277 2385 ...
#  $ nlcd_11           : num [1:717] 0.00229 0.00922 0.0029 0.04782 0.00113 ...
# ...

# %%
# pairs(ebird_features_df_pwo[c("mean_num_observers", "mean_start_time_hr", "med_duration", "mean_dist_km",
#         "dist_to_coast_mi", "elevation_ft", "Forest", "dominant_eco_group",
#         "tmean_2024_C", "ppt_2024_mm", "det_freq")])
pairs(ebird_features_df_pwo[c(
        "dist_to_coast_mi", "elevation_ft", "dominant_eco_group",
        "tmean_2024_C", "ppt_2024_mm", "det_freq")], pch = ".", col = "red")
# Out:
# plot without title

# %%
mod_add_pwo = lm(det_freq ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm,
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_add_pwo)
# Out:
# Call:
# lm(formula = det_freq ~ mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -5.8729 -0.3368 -0.0607  0.4602  4.9362
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  2.977e-01  1.912e-01   1.557 0.119960
# mean_num_observers          -2.649e-02  2.482e-02  -1.067 0.286164
# mean_start_time_hr          -1.261e-02  3.763e-03  -3.351 0.000849 ***
# med_duration                 1.132e-01  1.356e-02   8.343 3.82e-16 ***
# mean_dist_km                 8.221e-02  7.838e-03  10.489  < 2e-16 ***
# dist_to_coast_mi             1.667e-04  1.574e-04   1.059 0.289804
# elevation_ft                 6.648e-06  2.960e-05   0.225 0.822372
# ...

# %%
mod_int_pwo = lm(det_freq ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                         dist_to_coast_mi + elevation_ft + dominant_eco_group +
                         tmean_2024_C + ppt_2024_mm)^2,
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_int_pwo)
# Out:
# Call:
# lm(formula = det_freq ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm)^2, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -3.0140 -0.3235 -0.0778  0.3662  3.5192
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                    -2.397e+00  3.175e+00  -0.755
# mean_num_observers                             -1.167e+00  9.731e-01  -1.200
# mean_start_time_hr                              3.628e-02  1.788e-01   0.203
# med_duration                                   -1.566e-01  6.818e-01  -0.230
# mean_dist_km                                    1.828e+00  3.222e-01   5.672
# dist_to_coast_mi                                5.907e-03  5.815e-03   1.016
# ...

# %%
mod_add_pwo_logy = lm(log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm),
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_add_pwo_logy)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -21.1335  -1.3316  -0.2625   1.5555  14.2379
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -2.9074057  0.6936501  -4.191 3.12e-05 ***
# mean_num_observers          -0.0701050  0.0900222  -0.779 0.436387
# mean_start_time_hr          -0.0467404  0.0136506  -3.424 0.000653 ***
# med_duration                 0.3021841  0.0492033   6.142 1.37e-09 ***
# mean_dist_km                 0.2993085  0.0284306  10.528  < 2e-16 ***
# dist_to_coast_mi             0.0013354  0.0005710   2.339 0.019618 *
# elevation_ft                 0.0002402  0.0001074   2.236 0.025635 *
# ...

# %%
mod_int_pwo_logy = lm(log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm)^2,
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_int_pwo_logy)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm)^2, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -11.5015  -1.3560  -0.2191   1.3187  13.4555
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                    -1.844e+01  1.183e+01  -1.558
# mean_num_observers                             -3.024e+00  3.627e+00  -0.834
# mean_start_time_hr                              5.509e-01  6.665e-01   0.827
# med_duration                                   -1.428e+00  2.541e+00  -0.562
# mean_dist_km                                    7.276e+00  1.201e+00   6.059
# dist_to_coast_mi                                3.287e-02  2.167e-02   1.517
# ...

# %%
mod_add_pwo_recipy = lm(1/(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm),
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_add_pwo_recipy)
# Out:
# Call:
# lm(formula = 1/(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -75.155  -6.464   0.417   6.899  91.109
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 20.6397589  3.4257705   6.025 2.73e-09 ***
# mean_num_observers           0.1696579  0.4445979   0.382 0.702874
# mean_start_time_hr           0.2014758  0.0674168   2.989 0.002901 **
# med_duration                -0.9710979  0.2430031  -3.996 7.11e-05 ***
# mean_dist_km                -1.3539124  0.1404121  -9.642  < 2e-16 ***
# dist_to_coast_mi            -0.0099185  0.0028199  -3.517 0.000464 ***
# elevation_ft                -0.0019241  0.0005303  -3.628 0.000306 ***
# ...

# %%
anova(mod_add_pwo, mod_int_pwo)
# Out:
#   Res.Df RSS      Df Sum of Sq F        Pr(>F)
# 1 704    563.7936 NA      NA         NA           NA
# 2 644    328.1426 60 235.651   7.707994 5.411395e-45

# %%
mod_add_pwo_binom = glm(det_freq ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm),
                data = ebird_features_df_pwo, weight = n_checklists, family = binomial)
summary(mod_add_pwo_binom)
# Out:
# Call:
# glm(formula = det_freq ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), family = binomial,
#     data = ebird_features_df_pwo, weights = n_checklists)
#
# Coefficients:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -1.721e+00  6.200e-01  -2.776  0.00551 **
# mean_num_observers          -1.090e-01  7.527e-02  -1.448  0.14770
# mean_start_time_hr          -9.879e-02  1.237e-02  -7.987 1.39e-15 ***
# med_duration                 6.542e-01  3.797e-02  17.230  < 2e-16 ***
# mean_dist_km                 5.429e-01  2.306e-02  23.548  < 2e-16 ***
# dist_to_coast_mi             2.231e-03  5.059e-04   4.411 1.03e-05 ***
# elevation_ft                 1.309e-04  9.137e-05   1.433  0.15181
# dominant_eco_groupDeveloped -5.828e-01  7.989e-02  -7.295 2.99e-13 ***
# ...

# %%
mod_ = lm((det_freq+0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm),
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_)
# Out:
# Call:
# lm(formula = (det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -5.8729 -0.3368 -0.0607  0.4602  4.9362
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  3.977e-01  1.912e-01   2.080 0.037909 *
# mean_num_observers          -2.649e-02  2.482e-02  -1.067 0.286164
# mean_start_time_hr          -1.261e-02  3.763e-03  -3.351 0.000849 ***
# med_duration                 1.132e-01  1.356e-02   8.343 3.82e-16 ***
# mean_dist_km                 8.221e-02  7.838e-03  10.489  < 2e-16 ***
# dist_to_coast_mi             1.667e-04  1.574e-04   1.059 0.289804
# elevation_ft                 6.648e-06  2.960e-05   0.225 0.822372
# ...

# %% [markdown]
# ### Cross-validation and RMSE

# %% [markdown]
# #### base/full additive model

# %%
mod_add_pwo_form = det_freq ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm)
mod_add_pwo_train = lm(mod_add_pwo_form, data = ebird_features_df_pwo[ebird_features_df_pwo$type == "train", ], weight = n_checklists)
summary(mod_add_pwo_train)

# %%
# RMSE Of model - trained w/ whole dataset! (artificially low)
sqrt(mean(resid(mod_add_pwo)^2))
# Out:
# [1] 0.2331731

# %%
# RMSE of one manually-created fold
yhat = predict(mod_add_pwo_train, newdata = ebird_features_df_pwo[ebird_features_df_pwo$type == "test",])
y = ebird_features_df_pwo[ebird_features_df_pwo$type == "test",]$det_freq
e = y - yhat
sqrt(mean(e^2))
# Out:
# [1] 0.2662737

# %%
# avg RMSE across all 10 folds
train_control_k10 <- caret::trainControl(method = "cv", number = 10)
mod_add_pwo_cv_fit <- caret::train(
  form = mod_add_pwo_form,
  data = ebird_features_df_pwo,
  weights = n_checklists,
  method = "lm",
  trControl = train_control_k10
)
mod_add_pwo_cv_fit
# Out:
# Linear Regression
#
# 717 samples
#   9 predictor
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 647, 646, 646, 646, 644, 645, ...
# Resampling results:
#
#   RMSE       Rsquared   MAE
#   0.2334352  0.1520566  0.1634367
#
# Tuning parameter 'intercept' was held constant at a value of TRUE

# %%
mod_add_pwo_cv_fit$results[1,"RMSE"]
# Out:
# [1] 0.2334352

# %% [markdown]
# #### log-response

# %%
mod_add_pwo_logy_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm)
mod_add_pwo_logy_train = lm(mod_add_pwo_logy_form, data = ebird_features_df_pwo[ebird_features_df_pwo$type == "train", ], weight = n_checklists)
summary(mod_add_pwo_logy_train)

# %%
# RMSE Of model - trained w/ whole dataset! (artificially low)
transf_fitted = exp(predict(mod_add_pwo_logy)) - 0.1
residuals = transf_fitted - ebird_features_df_pwo$det_freq
sqrt(mean(residuals^2))
# Out:
# [1] 0.2358784

# %%
# RMSE of one manually-created fold
yhat = predict(mod_add_pwo_logy_train, newdata = ebird_features_df_pwo[ebird_features_df_pwo$type == "test",])
y = ebird_features_df_pwo[ebird_features_df_pwo$type == "test",]$det_freq
e = y - (e^yhat-0.1)
sqrt(mean(e^2))
# Out:
# [1] 0.4273663

# %%
# avg RMSE across all 10 folds
train_control_k10 <- caret::trainControl(method = "cv", number = 10, savePredictions = "final")
mod_add_pwo_logy_cv_fit <- caret::train(
  form = mod_add_pwo_logy_form,
  data = ebird_features_df_pwo,
  weights = n_checklists,
  method = "lm",
  trControl = train_control_k10
)

# RMSE on original detection-frequency scale
preds <- mod_add_pwo_logy_cv_fit$pred
preds$pred_original <- exp(preds$pred)-0.1
preds$obs_original  <- exp(preds$obs)-0.1

rmse_original <- sqrt(mean((preds$obs_original - preds$pred_original)^2))
rmse_original
# ChatGPT helped with this.
# Out:
# [1] 0.2382046

# %% [markdown]
# ### Transformations

# %%
preds = c("dist_to_coast_mi", "elevation_ft", "dominant_eco_group",
          "tmean_2024_C", "ppt_2024_mm", "det_freq")
pairs(ebird_features_df_pwo[preds], pch = ".", col = "red")
# Out:
# plot without title

# %%
# base additive model
par(mfrow = c(2, 2))
for (pred in preds[!preds %in% c("dominant_eco_group", "det_freq")]) {
    plot(ebird_features_df_pwo$det_freq ~ ebird_features_df_pwo[[pred]], main = paste("det_freq vs.", pred))
    abline(a = coef(mod_add_pwo)[1], b = coef(mod_add_pwo)[pred], col = "red")
}
# Out:
# Plot with title “det_freq vs. ppt_2024_mm”

# %%
# log response
par(mfrow = c(2, 2))
for (pred in preds[!preds %in% c("dominant_eco_group", "det_freq")]) {
    plot(log(ebird_features_df_pwo$det_freq+0.1) ~ ebird_features_df_pwo[[pred]], main = paste("det_freq vs.", pred))
    abline(a = coef(mod_add_pwo_logy)[1], b = coef(mod_add_pwo_logy)[pred], col = "red")
}
# Out:
# Plot with title “det_freq vs. ppt_2024_mm”

# %%
car::crPlots(mod_add_pwo)
# Out:
# plot without title

# %%
car::crPlots(mod_add_pwo_logy)
# Out:
# plot without title

# %%
# base, additive
visreg::visreg(mod_add_pwo)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# log-response
visreg::visreg(mod_add_pwo_logy)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
mod_base = lm(mod_add_pwo_logy_form, data = ebird_features_df_pwo, weight = n_checklists)
mod_new_term = lm(mod_pwo_logy_exp_form, data = ebird_features_df_pwo, weight = n_checklists)

xplot = seq(0, 2, 0.01)
xvar = "ppt_2024_mm"
xplot = seq(min(ebird_features_df_pwo[[xvar]]), max(ebird_features_df_pwo[[xvar]]), min(ebird_features_df_pwo[[xvar]])-max(ebird_features_df_pwo[[xvar]])/100)

plot(log(ebird_features_df_pwo$det_freq+0.1) ~ ebird_features_df_pwo[[xvar]], main = paste("det_freq vs.", xvar))
abline(a = coef(mod_base)[1], b = coef(mod_base)[xvar], col = "red")

# lines(ebird_features_df_pwo[[xvar]], newdata = predict(mod_new_term), col = "green")
# lines(xplot, predict(mod_new_term, newdata = data.frame(xvar = xplot)), col = "green")
# legend(x = "topright", legend = c("base", "w/ poly term"), col = c("red", "green"), pch = 1)

# %%
plot_poly_mod = function(mod, predictor, df = ebird_features_df_pwo) {
    # 1. Range of precipitation over which to plot the curve
    pred_seq <- seq(min(df[predictor]), max(df[predictor]), length.out = 300)
    # 2. Create a new data frame for prediction
    #    Fill all predictors with their mean values EXCEPT ppt_2024_mm
    newdat <- df[ rep(1, 300), ]             # duplicate one row
    newdat[predictor] <- pred_seq            # replace precip with sequence
    # Replace all other predictors with their means
    other_predictors <- names(df)[ names(df) != predictor ]
    for (p in other_predictors) {
        if (is.numeric(df[[p]])) newdat[[p]] <- mean(df[[p]], na.rm = TRUE)
    }
    # 3. Get predicted log(det_freq + 0.1)
    pred_curve <- predict(mod, newdata = newdat)
    # 4. Plot the scatterplot
    plot(log(df$det_freq + 0.1) ~ df[[predictor]],
         pch = 1,
         col = "black",
         main = paste("log(det_freq) vs.", predictor)
    )
    # 5. Add the polynomial prediction curve
    lines(pred_seq, pred_curve, col = "red", lwd = 3)

    plot(df$det_freq ~ df[[predictor]],
         pch = 1,
         col = "black",
         main = paste("det_freq vs.", predictor)
    )
    lines(pred_seq, exp(pred_curve) - 0.1, col = "blue", lwd = 3)
    # all from ChatGPT
}

# %%
plot_poly_mods = function(mod1, mod2, mod3, predictor, df = ebird_features_df_pwo) {
    # 1. Range of precipitation over which to plot the curve
    pred_seq <- seq(min(df[predictor]), max(df[predictor]), length.out = 300)
    # 2. Create a new data frame for prediction
    #    Fill all predictors with their mean values EXCEPT ppt_2024_mm
    newdat <- df[ rep(1, 300), ]             # duplicate one row
    newdat[predictor] <- pred_seq            # replace precip with sequence
    # Replace all other predictors with their means
    other_predictors <- names(df)[ names(df) != predictor ]
    for (p in other_predictors) {
        if (is.numeric(df[[p]])) newdat[[p]] <- mean(df[[p]], na.rm = TRUE)
    }
    # 3. Get predicted log(det_freq + 0.1)
    pred_curve_1 <- predict(mod1, newdata = newdat)
    pred_curve_2 <- predict(mod2, newdata = newdat)
    pred_curve_3 <- predict(mod3, newdata = newdat)

    # 4. Plot the scatterplot
    plot(log(df$det_freq + 0.1) ~ df[[predictor]],
         pch = 1,
         col = "black",
         main = paste("log(det_freq) vs.", predictor)
    )
    # 5. Add the polynomial prediction curve
    lines(pred_seq, pred_curve_1, col = "red", lwd = 3)
    lines(pred_seq, pred_curve_2, col = "blue", lwd = 3)
    lines(pred_seq, pred_curve_3, col = "green", lwd = 3)

    plot(df$det_freq ~ df[[predictor]],
         pch = 1,
         col = "black",
         main = paste("det_freq vs.", predictor)
    )
    lines(pred_seq, exp(pred_curve_1) - 0.1, col = "red", lwd = 3)
    lines(pred_seq, exp(pred_curve_2) - 0.1, col = "blue", lwd = 3)
    lines(pred_seq, exp(pred_curve_3) - 0.1, col = "green", lwd = 3)
    # all from ChatGPT
}

# %% [markdown]
# #### Poly terms: Mean distance

# %%
summary(mod_add_pwo_logy)
car::crPlots(mod_add_pwo_logy)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -21.1335  -1.3316  -0.2625   1.5555  14.2379
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -2.9074057  0.6936501  -4.191 3.12e-05 ***
# mean_num_observers          -0.0701050  0.0900222  -0.779 0.436387
# mean_start_time_hr          -0.0467404  0.0136506  -3.424 0.000653 ***
# med_duration                 0.3021841  0.0492033   6.142 1.37e-09 ***
# mean_dist_km                 0.2993085  0.0284306  10.528  < 2e-16 ***
# dist_to_coast_mi             0.0013354  0.0005710   2.339 0.019618 *
# elevation_ft                 0.0002402  0.0001074   2.236 0.025635 *
# ...

# %%
mod_pwo_logy_dist_poly2_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(mean_dist_km^2))
mod_pwo_logy_dist_poly2 = lm(mod_pwo_logy_dist_poly2_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_pwo_logy_dist_poly2)
# Out:
# Call:
# lm(formula = mod_pwo_logy_dist_poly2_form, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -20.0739  -1.2327  -0.1526   1.5845  13.8411
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -2.5806715  0.6921072  -3.729 0.000208 ***
# mean_num_observers          -0.1105676  0.0897618  -1.232 0.218440
# mean_start_time_hr          -0.0481760  0.0135230  -3.563 0.000392 ***
# med_duration                 0.3475108  0.0501210   6.933 9.32e-12 ***
# mean_dist_km                 0.5455295  0.0697466   7.822 1.91e-14 ***
# dist_to_coast_mi             0.0012425  0.0005659   2.195 0.028454 *
# elevation_ft                 0.0002280  0.0001064   2.143 0.032480 *
# dominant_eco_groupDeveloped -0.2824008  0.0952527  -2.965 0.003132 **
# dominant_eco_groupForest    -0.0419130  0.0962219  -0.436 0.663270
# ...

# %%
car::crPlots(mod_pwo_logy_dist_poly2)
# Out:
# plot without title
# plot without title

# %%
plot_poly_mods(mod_add_pwo_logy, mod_pwo_logy_dist_poly2, mod_pwo_logy_dist_poly2, predictor = "mean_dist_km")
# Out:
# Plot with title “log(det_freq) vs. mean_dist_km”
# Plot with title “det_freq vs. mean_dist_km”

# %% [markdown]
# #### Poly terms: Dist to coast

# %%
summary(mod_add_pwo_logy)
car::crPlots(mod_add_pwo_logy)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -21.1335  -1.3316  -0.2625   1.5555  14.2379
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -2.9074057  0.6936501  -4.191 3.12e-05 ***
# mean_num_observers          -0.0701050  0.0900222  -0.779 0.436387
# mean_start_time_hr          -0.0467404  0.0136506  -3.424 0.000653 ***
# med_duration                 0.3021841  0.0492033   6.142 1.37e-09 ***
# mean_dist_km                 0.2993085  0.0284306  10.528  < 2e-16 ***
# dist_to_coast_mi             0.0013354  0.0005710   2.339 0.019618 *
# elevation_ft                 0.0002402  0.0001074   2.236 0.025635 *
# ...

# %%
mod_pwo_logy_d2c_poly2_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(dist_to_coast_mi^2))
mod_pwo_logy_d2c_poly2 = lm(mod_pwo_logy_d2c_poly2_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_pwo_logy_d2c_poly2)
# Out:
# Call:
# lm(formula = mod_pwo_logy_d2c_poly2_form, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -20.0351  -1.4621  -0.3522   1.4200  14.7354
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -3.319e+00  6.864e-01  -4.836 1.63e-06 ***
# mean_num_observers          -6.267e-03  8.934e-02  -0.070 0.944092
# mean_start_time_hr          -5.099e-02  1.344e-02  -3.794 0.000161 ***
# med_duration                 2.785e-01  4.857e-02   5.734 1.46e-08 ***
# mean_dist_km                 2.952e-01  2.795e-02  10.562  < 2e-16 ***
# dist_to_coast_mi             5.098e-03  9.259e-04   5.506 5.14e-08 ***
# elevation_ft                 4.280e-04  1.117e-04   3.830 0.000139 ***
# dominant_eco_groupDeveloped -2.152e-01  9.333e-02  -2.306 0.021410 *
# dominant_eco_groupForest     2.663e-02  9.420e-02   0.283 0.777528
# ...

# %%
car::crPlots(mod_pwo_logy_d2c_poly2)
# Out:
# plot without title
# plot without title

# %%
mod_pwo_logy_d2c_poly4_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(dist_to_coast_mi^2)+I(dist_to_coast_mi^3)+I(dist_to_coast_mi^4))
mod_pwo_logy_d2c_poly4 = lm(mod_pwo_logy_d2c_poly4_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
car::crPlots(mod_pwo_logy_d2c_poly4)
# Out:
# plot without title
# plot without title

# %%
plot_poly_mods(mod_add_pwo_logy, mod_pwo_logy_d2c_poly2, mod_pwo_logy_d2c_poly4, predictor = "dist_to_coast_mi")
# Out:
# Plot with title “log(det_freq) vs. dist_to_coast_mi”
# Plot with title “det_freq vs. dist_to_coast_mi”

# %% [markdown]
# #### Poly terms: Precip

# %%
summary(mod_add_pwo_logy)
car::crPlots(mod_add_pwo_logy)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -21.1335  -1.3316  -0.2625   1.5555  14.2379
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -2.9074057  0.6936501  -4.191 3.12e-05 ***
# mean_num_observers          -0.0701050  0.0900222  -0.779 0.436387
# mean_start_time_hr          -0.0467404  0.0136506  -3.424 0.000653 ***
# med_duration                 0.3021841  0.0492033   6.142 1.37e-09 ***
# mean_dist_km                 0.2993085  0.0284306  10.528  < 2e-16 ***
# dist_to_coast_mi             0.0013354  0.0005710   2.339 0.019618 *
# elevation_ft                 0.0002402  0.0001074   2.236 0.025635 *
# ...

# %%
mod_pwo_logy_ppt_poly2_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(ppt_2024_mm^2))
mod_pwo_logy_ppt_poly2 = lm(mod_pwo_logy_ppt_poly2_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_pwo_logy_ppt_poly2)
# Out:
# Call:
# lm(formula = mod_pwo_logy_ppt_poly2_form, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -20.2555  -1.3903  -0.2809   1.5964  15.8387
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -4.630e-02  8.199e-01  -0.056 0.954986
# mean_num_observers          -1.124e-01  8.801e-02  -1.278 0.201837
# mean_start_time_hr          -5.146e-02  1.333e-02  -3.861 0.000123 ***
# med_duration                 3.052e-01  4.796e-02   6.363 3.57e-10 ***
# mean_dist_km                 2.782e-01  2.792e-02   9.962  < 2e-16 ***
# dist_to_coast_mi             3.864e-03  6.913e-04   5.590 3.24e-08 ***
# elevation_ft                -2.319e-04  1.297e-04  -1.788 0.074168 .
# dominant_eco_groupDeveloped -2.563e-01  9.271e-02  -2.765 0.005841 **
# dominant_eco_groupForest     1.311e-02  9.343e-02   0.140 0.888469
# ...

# %%
car::crPlots(mod_pwo_logy_ppt_poly2)
# Out:
# plot without title
# plot without title

# %%
mod_pwo_logy_ppt_poly4_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(ppt_2024_mm^2)+I(ppt_2024_mm^3)+I(ppt_2024_mm^4))
mod_pwo_logy_ppt_poly4 = lm(mod_pwo_logy_ppt_poly4_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
car::crPlots(mod_pwo_logy_ppt_poly4)
# Out:
# plot without title
# plot without title

# %%
plot_poly_mods(mod_add_pwo_logy, mod_pwo_logy_ppt_poly2, mod_pwo_logy_ppt_poly4, predictor = "ppt_2024_mm")
# Out:
# Plot with title “log(det_freq) vs. ppt_2024_mm”
# Plot with title “det_freq vs. ppt_2024_mm”

# %% [markdown]
# #### Poly terms: Temp

# %%
summary(mod_add_pwo_logy)
car::crPlots(mod_add_pwo_logy)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -21.1335  -1.3316  -0.2625   1.5555  14.2379
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -2.9074057  0.6936501  -4.191 3.12e-05 ***
# mean_num_observers          -0.0701050  0.0900222  -0.779 0.436387
# mean_start_time_hr          -0.0467404  0.0136506  -3.424 0.000653 ***
# med_duration                 0.3021841  0.0492033   6.142 1.37e-09 ***
# mean_dist_km                 0.2993085  0.0284306  10.528  < 2e-16 ***
# dist_to_coast_mi             0.0013354  0.0005710   2.339 0.019618 *
# elevation_ft                 0.0002402  0.0001074   2.236 0.025635 *
# ...

# %%
mod_pwo_logy_temp_poly2_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(tmean_2024_C^2))
mod_pwo_logy_temp_poly2 = lm(mod_pwo_logy_temp_poly2_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_pwo_logy_temp_poly2)
# Out:
# Call:
# lm(formula = mod_pwo_logy_temp_poly2_form, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -22.2750  -1.3165  -0.2167   1.5996  13.6972
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  1.191e+01  5.436e+00   2.192 0.028735 *
# mean_num_observers          -6.325e-02  8.964e-02  -0.706 0.480677
# mean_start_time_hr          -4.848e-02  1.360e-02  -3.564 0.000390 ***
# med_duration                 3.099e-01  4.906e-02   6.317 4.72e-10 ***
# mean_dist_km                 2.920e-01  2.843e-02  10.271  < 2e-16 ***
# dist_to_coast_mi             2.299e-03  6.677e-04   3.443 0.000610 ***
# elevation_ft                -5.438e-05  1.513e-04  -0.359 0.719492
# dominant_eco_groupDeveloped -2.106e-01  9.465e-02  -2.225 0.026392 *
# dominant_eco_groupForest     1.765e-02  9.541e-02   0.185 0.853269
# ...

# %%
car::crPlots(mod_pwo_logy_temp_poly2)
# Out:
# plot without title
# plot without title

# %%
mod_pwo_logy_temp_poly3_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(tmean_2024_C^2)+I(tmean_2024_C^3))
mod_pwo_logy_temp_poly3 = lm(mod_pwo_logy_temp_poly3_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_pwo_logy_temp_poly3)
# Out:
# Call:
# lm(formula = mod_pwo_logy_temp_poly3_form, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -20.7306  -1.4072  -0.2825   1.5796  14.7930
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  1.117e+02  2.469e+01   4.526 7.05e-06 ***
# mean_num_observers          -6.795e-02  8.863e-02  -0.767 0.443562
# mean_start_time_hr          -4.674e-02  1.345e-02  -3.474 0.000545 ***
# med_duration                 3.175e-01  4.854e-02   6.542 1.17e-10 ***
# mean_dist_km                 2.810e-01  2.823e-02   9.953  < 2e-16 ***
# dist_to_coast_mi             3.899e-03  7.648e-04   5.098 4.43e-07 ***
# elevation_ft                -2.598e-04  1.576e-04  -1.648 0.099822 .
# dominant_eco_groupDeveloped -2.310e-01  9.371e-02  -2.465 0.013944 *
# dominant_eco_groupForest     2.260e-02  9.434e-02   0.240 0.810709
# ...

# %%
plot_poly_mods(mod_add_pwo_logy, mod_pwo_logy_temp_poly2, mod_pwo_logy_temp_poly3, "tmean_2024_C")
# Out:
# Plot with title “log(det_freq) vs. tmean_2024_C”
# Plot with title “det_freq vs. tmean_2024_C”

# %% [markdown]
# #### Poly terms: Elevation

# %%
summary(mod_add_pwo_logy)
car::crPlots(mod_add_pwo_logy)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -21.1335  -1.3316  -0.2625   1.5555  14.2379
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -2.9074057  0.6936501  -4.191 3.12e-05 ***
# mean_num_observers          -0.0701050  0.0900222  -0.779 0.436387
# mean_start_time_hr          -0.0467404  0.0136506  -3.424 0.000653 ***
# med_duration                 0.3021841  0.0492033   6.142 1.37e-09 ***
# mean_dist_km                 0.2993085  0.0284306  10.528  < 2e-16 ***
# dist_to_coast_mi             0.0013354  0.0005710   2.339 0.019618 *
# elevation_ft                 0.0002402  0.0001074   2.236 0.025635 *
# ...

# %%
mod_pwo_logy_elev_poly2_form = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                                               dist_to_coast_mi + elevation_ft + dominant_eco_group +
                                               tmean_2024_C + ppt_2024_mm
                                              +I(elevation_ft^2))
mod_pwo_logy_elev_poly2 = lm(mod_pwo_logy_elev_poly2_form,
                            data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_pwo_logy_elev_poly2)
# Out:
# Call:
# lm(formula = mod_pwo_logy_elev_poly2_form, data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -20.4570  -1.3897  -0.2976   1.6205  15.3781
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -3.278e+00  6.739e-01  -4.864 1.42e-06 ***
# mean_num_observers          -5.697e-02  8.720e-02  -0.653 0.513765
# mean_start_time_hr          -4.599e-02  1.322e-02  -3.479 0.000534 ***
# med_duration                 3.521e-01  4.820e-02   7.306 7.49e-13 ***
# mean_dist_km                 2.598e-01  2.812e-02   9.236  < 2e-16 ***
# dist_to_coast_mi             5.676e-03  8.377e-04   6.776 2.61e-11 ***
# elevation_ft                -1.087e-03  2.187e-04  -4.970 8.40e-07 ***
# dominant_eco_groupDeveloped -2.568e-01  9.209e-02  -2.789 0.005433 **
# dominant_eco_groupForest     1.853e-02  9.283e-02   0.200 0.841866
# ...

# %%
car::crPlots(mod_pwo_logy_elev_poly2)
# Out:
# plot without title
# plot without title

# %%
plot_poly_mods(mod_add_pwo_logy, mod_pwo_logy_elev_poly2, mod_pwo_logy_elev_poly2, "elevation_ft")
# Out:
# Plot with title “log(det_freq) vs. elevation_ft”
# Plot with title “det_freq vs. elevation_ft”

# %% [markdown]
# ### Collinearity

# %%
cor(select(ebird_features_df_pwo, mean_num_observers, mean_start_time_hr, med_duration, mean_dist_km,
                        dist_to_coast_mi, elevation_ft,
                        tmean_2024_C, ppt_2024_mm, det_freq))
# Out:
#                    mean_num_observers mean_start_time_hr med_duration
# mean_num_observers  1.000000000        0.001156058        0.094742867
# mean_start_time_hr  0.001156058        1.000000000       -0.141348766
# med_duration        0.094742867       -0.141348766        1.000000000
# mean_dist_km        0.197313870       -0.054656688        0.292164918
# dist_to_coast_mi   -0.113966915        0.031555340       -0.049021037
# elevation_ft       -0.051168626       -0.006945814       -0.001694957
# tmean_2024_C        0.092337689       -0.028316425        0.017954762
# ppt_2024_mm         0.033556274       -0.091877185        0.038975002
# det_freq            0.124953815       -0.200040487        0.303986378
#                    mean_dist_km dist_to_coast_mi elevation_ft tmean_2024_C
# mean_num_observers  0.19731387  -0.11396692      -0.051168626  0.09233769
# mean_start_time_hr -0.05465669   0.03155534      -0.006945814 -0.02831642
# ...

# %%
# detach("package:faraway", unload=TRUE)
library(car)
(vif_car = car::vif(mod_add_pwo))
# vif(mod_add_pwo_logy) # same values
# Out:
#                    GVIF     Df GVIF^(1/(2*Df))
# mean_num_observers 1.380744 1  1.175051
# mean_start_time_hr 1.044553 1  1.022034
# med_duration       1.237466 1  1.112415
# mean_dist_km       1.502604 1  1.225807
# dist_to_coast_mi   8.336528 1  2.887305
# elevation_ft       9.250157 1  3.041407
# dominant_eco_group 2.865453 4  1.140641
# tmean_2024_C       9.348950 1  3.057605
# ppt_2024_mm        2.076651 1  1.441059

# %%
# detach("package:car", unload=TRUE)
# detach("package:faraway", unload=TRUE)
library(faraway)
(vif_faraway = faraway::vif(mod_add_pwo))
# vif(mod_add_pwo_logy) # same
# Out:
#          mean_num_observers          mean_start_time_hr
#                  0.08634464                  0.05573187
#                med_duration                mean_dist_km
#                  0.03743972                  0.04668988
#            dist_to_coast_mi                elevation_ft
#                  0.08615443                  0.11990145
# dominant_eco_groupDeveloped    dominant_eco_groupForest
#                  0.05128551                  0.15538389
#     dominant_eco_groupWater   dominant_eco_groupWetland
#                  0.02344312                  0.14436752
#                tmean_2024_C                 ppt_2024_mm
#                  0.09859585                  0.03237255

# %%
mod_add_pwo = lm(det_freq ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm,
                data = ebird_features_df_pwo, weight = n_checklists)

# %%
mod_add_pwo__mean_num_observers = lm(mean_num_observers ~  mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm,
                data = ebird_features_df_pwo, weight = n_checklists)

# %%
cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_dist_km))
# Out:
# [1] -0.2210562

# %%
cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_dist_km))^2
# Out:
# [1] 0.04886584

# %%
summary(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__mean_dist_km)))$r.squared
# Out:
# [1] 0.04886584

# %%
# vif_faraway[!names(vif_faraway) %in% c('name1', 'name2')]

vif_faraway[!startsWith(names(vif_faraway), "dominant_eco_group") ]
# Out:
# mean_num_observers mean_start_time_hr       med_duration       mean_dist_km
#         0.08634464         0.05573187         0.03743972         0.04668988
#   dist_to_coast_mi       elevation_ft       tmean_2024_C        ppt_2024_mm
#         0.08615443         0.11990145         0.09859585         0.03237255

# %%
1 / (1 - (0.5)^2)
# Out:
# [1] 1.333333

# %%
1 / (1-(-.221)^2)
# Out:
# [1] 1.051349

# %%
# Partial correlation coefficients
data.frame(
    # predictor = c("mean_num_observers", "mean_start_time_hr", "med_duration", "mean_dist_km",
    #               "dist_to_coast_mi", "elevation_ft",
    #               "tmean_2024_C", "ppt_2024_mm"),
    cor = c(
        cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_num_observers)),
        cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_start_time_hr)),
        cor(resid(mod_add_pwo), resid(mod_add_pwo__med_duration)),
        cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_dist_km)),
        cor(resid(mod_add_pwo), resid(mod_add_pwo__dist_to_coast_mi)),
        cor(resid(mod_add_pwo), resid(mod_add_pwo__elevation_ft)),
        cor(resid(mod_add_pwo), resid(mod_add_pwo__tmean_2024_C)),
        cor(resid(mod_add_pwo), resid(mod_add_pwo__ppt_2024_mm))),
    Rj2 = c(
        cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_num_observers))^2,
        cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_start_time_hr))^2,
        cor(resid(mod_add_pwo), resid(mod_add_pwo__med_duration))^2,
        cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_dist_km))^2,
        cor(resid(mod_add_pwo), resid(mod_add_pwo__dist_to_coast_mi))^2,
        cor(resid(mod_add_pwo), resid(mod_add_pwo__elevation_ft))^2,
        cor(resid(mod_add_pwo), resid(mod_add_pwo__tmean_2024_C))^2,
        cor(resid(mod_add_pwo), resid(mod_add_pwo__ppt_2024_mm))^2),
    VIF_manual = c(
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_num_observers))^2),
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_start_time_hr))^2),
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__med_duration))^2),
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__mean_dist_km))^2),
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__dist_to_coast_mi))^2),
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__elevation_ft))^2),
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__tmean_2024_C))^2),
        1 / (1- cor(resid(mod_add_pwo), resid(mod_add_pwo__ppt_2024_mm))^2)),
    VIF_faraway = faraway::vif(mod_add_pwo)[!startsWith(names(faraway::vif(mod_add_pwo)), "dominant_eco_group") ],
    VIF_car = car::vif(mod_add_pwo)[rownames(car::vif(mod_add_pwo)) != "dominant_eco_group",]
)
# Out:
#                    cor         Rj2          VIF_manual VIF_faraway VIF_car.GVIF
# mean_num_observers  0.12602778 0.0158830008 1.016139   0.08634464  1.380744
# mean_start_time_hr -0.05313686 0.0028235259 1.002832   0.05573187  1.044553
# med_duration        0.04793207 0.0022974836 1.002303   0.03743972  1.237466
# mean_dist_km       -0.22105619 0.0488658408 1.051376   0.04668988  1.502604
# dist_to_coast_mi    0.07418028 0.0055027146 1.005533   0.08615443  8.336528
# elevation_ft       -0.09312755 0.0086727407 1.008749   0.11990145  9.250157
# tmean_2024_C        0.02230297 0.0004974224 1.000498   0.09859585  9.348950
# ppt_2024_mm         0.11711724 0.0137164488 1.013907   0.03237255  2.076651
#                    VIF_car.Df VIF_car.GVIF..1..2.Df..
# mean_num_observers 1          1.175051
# mean_start_time_hr 1          1.022034
# med_duration       1          1.112415
# mean_dist_km       1          1.225807
# dist_to_coast_mi   1          2.887305
# ...

# %%
par(mfrow = c(3, 3))
plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__mean_num_observers), main = "Var-added: mean_num_observers")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__mean_num_observers)), col = "red")

plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__med_duration), main = "Var-added: med_duration")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__med_duration)), col = "red")

plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__mean_dist_km), main = "Var-added: mean_dist_km")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__mean_dist_km)), col = "red")

plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__med_duration), main = "Var-added: med_duration")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__med_duration)), col = "red")

plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__dist_to_coast_mi), main = "Var-added: dist_to_coast_mi")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__dist_to_coast_mi)), col = "red")

plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__elevation_ft), main = "Var-added: elevation_ft")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__elevation_ft)), col = "red")

plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__tmean_2024_C), main = "Var-added: tmean_2024_C")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__tmean_2024_C)), col = "red")

plot(resid(mod_add_pwo) ~ resid(mod_add_pwo__ppt_2024_mm), main = "Var-added: ppt_2024_mm")
abline(h = 0, lty = 2)
abline(v = 0, lty = 2)
abline(lm(resid(mod_add_pwo) ~ resid(mod_add_pwo__ppt_2024_mm)), col = "red")
# Out:
# Plot with title “Var-added: ppt_2024_mm”

# %%
summary(mod_add_pwo)$coefficients
# Out:
#                             Estimate      Std. Error   t value    Pr(>|t|)
# (Intercept)                  2.977115e-01 1.912293e-01  1.5568305 1.199601e-01
# mean_num_observers          -2.649013e-02 2.481781e-02 -1.0673838 2.861644e-01
# mean_start_time_hr          -1.261029e-02 3.763259e-03 -3.3508954 8.485116e-04
# med_duration                 1.131655e-01 1.356463e-02  8.3426951 3.824793e-16
# mean_dist_km                 8.220881e-02 7.837914e-03 10.4886082 5.158027e-24
# dist_to_coast_mi             1.667499e-04 1.574077e-04  1.0593501 2.898037e-01
# elevation_ft                 6.648345e-06 2.960365e-05  0.2245785 8.223723e-01
# dominant_eco_groupDeveloped -7.320923e-02 2.617991e-02 -2.7963893 5.308678e-03
# dominant_eco_groupForest    -1.996548e-02 2.642583e-02 -0.7555289 4.501844e-01
# dominant_eco_groupWater     -8.114992e-02 2.844912e-02 -2.8524582 4.465481e-03
# dominant_eco_groupWetland    3.968237e-02 2.749990e-02  1.4430005 1.494651e-01
# ...

# %%
summary(lm(det_freq ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm,
                data = ebird_features_df_pwo, weight = n_checklists))$coefficients
# Out:
#                             Estimate      Std. Error   t value    Pr(>|t|)
# (Intercept)                  1.311502e-01 6.692827e-02  1.9595632 5.043995e-02
# mean_num_observers          -2.278619e-02 2.454748e-02 -0.9282496 3.535953e-01
# mean_start_time_hr          -1.258577e-02 3.761143e-03 -3.3462612 8.624681e-04
# med_duration                 1.147999e-01 1.347302e-02  8.5207264 9.556994e-17
# mean_dist_km                 8.094407e-02 7.564497e-03 10.7005234 7.234513e-25
# dist_to_coast_mi             3.097842e-04 8.673356e-05  3.5716765 3.787833e-04
# dominant_eco_groupDeveloped -7.593264e-02 2.604108e-02 -2.9158796 3.659303e-03
# dominant_eco_groupForest    -1.993093e-02 2.639791e-02 -0.7550191 4.504893e-01
# dominant_eco_groupWater     -8.565530e-02 2.801237e-02 -3.0577669 2.314169e-03
# dominant_eco_groupWetland    3.641377e-02 2.730336e-02  1.3336733 1.827410e-01
# ppt_2024_mm                  2.053498e-05 2.631904e-05  0.7802330 4.355152e-01

# %% [markdown]
# ### Diagnostics (LINE)

# %% [markdown]
# #### Original full model

# %%
qqnorm(resid(mod_add_pwo), col = "red")
qqline(resid(mod_add_pwo))
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
plot(resid(mod_add_pwo) ~ fitted(mod_add_pwo), col = "blue")
# Out:
# plot without title

# %%
shapiro.test(resid(mod_add_pwo))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  resid(mod_add_pwo)
# W = 0.89824, p-value < 2.2e-16

# %%
library(lmtest)
bptest(mod_add_pwo)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod_add_pwo
# BP = 55010, df = 12, p-value < 2.2e-16

# %%
n = nrow(ebird_features_df_pwo)
p = length(coef(mod_add_pwo))
(h_mean = p / n)
# (h_mean = mean(hatvalues(mod_int_pwo))) # same
# Out:
# [1] 0.0181311

# %%
# high leverage
nrow(ebird_features_df_pwo[hatvalues(mod_add_pwo) > 2*h_mean,])
nrow(ebird_features_df_pwo[hatvalues(mod_add_pwo) > 2*h_mean,]) / n
# Out:
# [1] 94
# [1] 0.1311018

# %%
# outliers
sum(abs(rstandard(mod_add_pwo)) > 2) / n
# Out:
# [1] 0.05718271

# %%
# high Cook's distance
n = nrow(ebird_features_df_pwo)
nrow(ebird_features_df_pwo[cooks.distance(mod_add_pwo) > 4/n,])
nrow(ebird_features_df_pwo[cooks.distance(mod_add_pwo) > 4/n,]) / n
# Out:
# [1] 74
# [1] 0.1032078

# %% [markdown]
# #### log(y) response

# %%
qqnorm(resid(mod_add_pwo_logy), col = "green")
qqline(resid(mod_add_pwo_logy))
shapiro.test(resid(mod_add_pwo_logy))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  resid(mod_add_pwo_logy)
# W = 0.99629, p-value = 0.09014
# Plot with title “Normal Q-Q Plot”

# %%
plot(resid(mod_add_pwo_logy) ~ fitted(mod_add_pwo_logy), col = "blue")
lmtest::bptest(mod_add_pwo_logy)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod_add_pwo_logy
# BP = 54099, df = 12, p-value < 2.2e-16
# plot without title

# %%
n = nrow(ebird_features_df_pwo)
p = length(coef(mod_add_pwo_logy))
(h_mean = p / n)
# (h_mean = mean(hatvalues(mod_int_pwo))) # same
# Out:
# [1] 0.0181311

# %%
# high leverage
nrow(ebird_features_df_pwo[hatvalues(mod_add_pwo_logy) > 2*h_mean,])
nrow(ebird_features_df_pwo[hatvalues(mod_add_pwo_logy) > 2*h_mean,]) / n
# Out:
# [1] 94
# [1] 0.1311018

# %%
# outliers
sum(abs(rstandard(mod_add_pwo_logy)) > 2) / n
# Out:
# [1] 0.06136681

# %%
# high Cook's distance
n = nrow(ebird_features_df_pwo)
nrow(ebird_features_df_pwo[cooks.distance(mod_add_pwo_logy) > 4/n,])
nrow(ebird_features_df_pwo[cooks.distance(mod_add_pwo_logy) > 4/n,]) / n
# Out:
# [1] 82
# [1] 0.1143654

# %% [markdown]
# #### log(y) response, 20km hex cells

# %%
mod_add_pwo_logy_20km_hex = lm(log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm),
                data = ebird_features_df_pwo_20km_hexes, weight = n_checklists)
summary(mod_add_pwo_logy_20km_hex)
# Out:
# Call:
# lm(formula = log(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo_20km_hexes,
#     weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -17.186  -1.306   0.801   2.333  17.966
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -4.533e+00  9.868e-01  -4.594 6.87e-06 ***
# mean_num_observers          -1.287e-01  1.741e-01  -0.739  0.46035
# mean_start_time_hr          -7.723e-02  2.376e-02  -3.250  0.00131 **
# med_duration                 3.655e-01  8.269e-02   4.420 1.46e-05 ***
# mean_dist_km                 2.296e-01  4.989e-02   4.603 6.61e-06 ***
# dist_to_coast_mi             2.470e-03  8.394e-04   2.942  0.00356 **
# elevation_ft                 3.458e-05  1.353e-04   0.256  0.79845
# ...

# %%
qqnorm(resid(mod_add_pwo_logy_20km_hex), col = "green")
qqline(resid(mod_add_pwo_logy_20km_hex))
shapiro.test(resid(mod_add_pwo_logy_20km_hex))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  resid(mod_add_pwo_logy_20km_hex)
# W = 0.9926, p-value = 0.2075
# Plot with title “Normal Q-Q Plot”

# %%
plot(resid(mod_add_pwo_logy_20km_hex) ~ fitted(mod_add_pwo_logy_20km_hex), col = "blue")
lmtest::bptest(mod_add_pwo_logy_20km_hex)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod_add_pwo_logy_20km_hex
# BP = 48622, df = 12, p-value < 2.2e-16
# plot without title

# %% [markdown]
# #### recip(y) response

# %%
mod_add_pwo_recipy = lm(1/(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                        dist_to_coast_mi + elevation_ft + dominant_eco_group +
                        tmean_2024_C + ppt_2024_mm),
                data = ebird_features_df_pwo, weight = n_checklists)
summary(mod_add_pwo_recipy)
# Out:
# Call:
# lm(formula = 1/(det_freq + 0.1) ~ (mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm), data = ebird_features_df_pwo,
#     weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -75.155  -6.464   0.417   6.899  91.109
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 20.6397589  3.4257705   6.025 2.73e-09 ***
# mean_num_observers           0.1696579  0.4445979   0.382 0.702874
# mean_start_time_hr           0.2014758  0.0674168   2.989 0.002901 **
# med_duration                -0.9710979  0.2430031  -3.996 7.11e-05 ***
# mean_dist_km                -1.3539124  0.1404121  -9.642  < 2e-16 ***
# dist_to_coast_mi            -0.0099185  0.0028199  -3.517 0.000464 ***
# elevation_ft                -0.0019241  0.0005303  -3.628 0.000306 ***
# ...

# %%
qqnorm(resid(mod_add_pwo_recipy), col = "green")
qqline(resid(mod_add_pwo_recipy))
shapiro.test(resid(mod_add_pwo_recipy))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  resid(mod_add_pwo_recipy)
# W = 0.97334, p-value = 3.778e-10
# Plot with title “Normal Q-Q Plot”

# %%
plot(resid(mod_add_pwo_recipy) ~ fitted(mod_add_pwo_recipy), col = "blue")
lmtest::bptest(mod_add_pwo_recipy)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod_add_pwo_recipy
# BP = 53950, df = 12, p-value < 2.2e-16
# plot without title

# %% [markdown]
# ### standardizing

# %%
det_freq = ebird_features_df_pwo$det_freq

standardized_ebird = scale(cbind(select(ebird_features_df_pwo, mean_num_observers,
                                        mean_start_time_hr,
                                        med_duration,
                                        mean_dist_km,
                                        dist_to_coast_mi,
                                        elevation_ft,
                                        tmean_2024_C,
                                        ppt_2024_mm),
                                 det_freq_log))
ebird_features_df_pwo_std = cbind(cell = ebird_features_df_pwo$cell, standardized_ebird, dominant_eco_group = ebird_features_df_pwo$dominant_eco_group,  n_checklists = ebird_features_df_pwo$n_checklists) %>%
    as.data.frame()
ebird_features_df_pwo_std$dominant_eco_group <- as.factor(ebird_features_df_pwo_std$dominant_eco_group)
str(ebird_features_df_pwo_std)
# Out:
# 'data.frame':	717 obs. of  12 variables:
#  $ cell              : num  493475 493476 493477 493478 493479 ...
#  $ mean_num_observers: num  1.823 0.675 -0.38 -0.198 1.823 ...
#  $ mean_start_time_hr: num  0.373 -0.898 -0.162 -1.04 -0.36 ...
#  $ med_duration      : num  -0.792 3.26 -0.443 -0.967 0.605 ...
#  $ mean_dist_km      : num  -0.0411 1.2548 -0.7473 -0.7297 1.442 ...
#  $ dist_to_coast_mi  : num  1.99 1.95 1.91 1.88 1.85 ...
#  $ elevation_ft      : num  5.99 6.8 6.4 4.93 5.21 ...
#  $ tmean_2024_C      : num  -4.19 -4.41 -3.48 -3.23 -2.93 ...
#  $ ppt_2024_mm       : num  5.5 6.07 4.75 3.47 2.77 ...
#  $ det_freq_log      : num  -1.1 1.75 1.19 0.38 1.32 ...
#  $ dominant_eco_group: Factor w/ 5 levels "1","2","3","4",..: 3 3 3 3 3 3 3 3 3 3 ...
#  $ n_checklists      : num  1 11 180 20 10 2 35 5 15 91 ...

# %%
mod_add_pwo_std = lm(det_freq_log ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                     dist_to_coast_mi + elevation_ft + dominant_eco_group +
                     tmean_2024_C + ppt_2024_mm,
                     data = ebird_features_df_pwo_logy_std, weight = n_checklists)
summary(mod_add_pwo_std)

# %%
# recip response
det_freq_recip = 1/(ebird_features_df_pwo$det_freq + 0.1)

standardized_ebird = scale(cbind(select(ebird_features_df_pwo, mean_num_observers,
                                        mean_start_time_hr,
                                        med_duration,
                                        mean_dist_km,
                                        dist_to_coast_mi,
                                        elevation_ft,
                                        tmean_2024_C,
                                        ppt_2024_mm),
                                 det_freq_log))
ebird_features_df_pwo_recipy_std = cbind(cell = ebird_features_df_pwo$cell, standardized_ebird, dominant_eco_group = ebird_features_df_pwo$dominant_eco_group,  n_checklists = ebird_features_df_pwo$n_checklists) %>%
    as.data.frame()
ebird_features_df_pwo_recipy_std$dominant_eco_group <- as.factor(ebird_features_df_pwo_recipy_std$dominant_eco_group)
str(ebird_features_df_pwo_recipy_std)
# Out:
# 'data.frame':	717 obs. of  12 variables:
#  $ cell              : num  493475 493476 493477 493478 493479 ...
#  $ mean_num_observers: num  1.823 0.675 -0.38 -0.198 1.823 ...
#  $ mean_start_time_hr: num  0.373 -0.898 -0.162 -1.04 -0.36 ...
#  $ med_duration      : num  -0.792 3.26 -0.443 -0.967 0.605 ...
#  $ mean_dist_km      : num  -0.0411 1.2548 -0.7473 -0.7297 1.442 ...
#  $ dist_to_coast_mi  : num  1.99 1.95 1.91 1.88 1.85 ...
#  $ elevation_ft      : num  5.99 6.8 6.4 4.93 5.21 ...
#  $ tmean_2024_C      : num  -4.19 -4.41 -3.48 -3.23 -2.93 ...
#  $ ppt_2024_mm       : num  5.5 6.07 4.75 3.47 2.77 ...
#  $ det_freq_log      : num  1.27 -1.28 -1.09 -0.66 -1.14 ...
#  $ dominant_eco_group: Factor w/ 5 levels "1","2","3","4",..: 3 3 3 3 3 3 3 3 3 3 ...
#  $ n_checklists      : num  1 11 180 20 10 2 35 5 15 91 ...

# %%
mod_add_pwo_recipy_std = lm(det_freq_recip ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                     dist_to_coast_mi + elevation_ft + dominant_eco_group +
                     tmean_2024_C + ppt_2024_mm,
                     data = ebird_features_df_pwo_recipy_std, weight = n_checklists)
summary(mod_add_pwo_recipy_std)
# Out:
# Call:
# lm(formula = det_freq_recip ~ mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm, data = ebird_features_df_pwo_recipy_std,
#     weights = n_checklists)
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -75.155  -6.464   0.417   6.899  91.109
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)          5.11274    0.44726  11.431  < 2e-16 ***
# mean_num_observers   0.06718    0.17605   0.382 0.702874
# mean_start_time_hr   0.42270    0.14144   2.989 0.002901 **
# med_duration        -0.46327    0.11593  -3.996 7.11e-05 ***
# mean_dist_km        -1.24830    0.12946  -9.642  < 2e-16 ***
# dist_to_coast_mi    -0.61855    0.17586  -3.517 0.000464 ***
# elevation_ft        -0.75270    0.20746  -3.628 0.000306 ***
# dominant_eco_group2  0.79283    0.46900   1.690 0.091380 .
# ...

# %%
plot(resid(mod_add_pwo_recipy_std) ~ fitted(mod_add_pwo_recipy_std))
bptest(mod_add_pwo_recipy_std)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod_add_pwo_recipy_std
# BP = 53950, df = 12, p-value < 2.2e-16
# plot without title

# %%
# log response
det_freq_log = log(ebird_features_df_pwo$det_freq + 0.1)

standardized_ebird = scale(cbind(select(ebird_features_df_pwo, mean_num_observers,
                                        mean_start_time_hr,
                                        med_duration,
                                        mean_dist_km,
                                        dist_to_coast_mi,
                                        elevation_ft,
                                        tmean_2024_C,
                                        ppt_2024_mm),
                                 det_freq_log))
ebird_features_df_pwo_logy_std = cbind(cell = ebird_features_df_pwo$cell, standardized_ebird, dominant_eco_group = ebird_features_df_pwo$dominant_eco_group,  n_checklists = ebird_features_df_pwo$n_checklists) %>%
    as.data.frame()
ebird_features_df_pwo_logy_std$dominant_eco_group <- as.factor(ebird_features_df_pwo_logy_std$dominant_eco_group)
str(ebird_features_df_pwo_logy_std)
# Out:
# 'data.frame':	717 obs. of  12 variables:
#  $ cell              : num  493475 493476 493477 493478 493479 ...
#  $ mean_num_observers: num  1.823 0.675 -0.38 -0.198 1.823 ...
#  $ mean_start_time_hr: num  0.373 -0.898 -0.162 -1.04 -0.36 ...
#  $ med_duration      : num  -0.792 3.26 -0.443 -0.967 0.605 ...
#  $ mean_dist_km      : num  -0.0411 1.2548 -0.7473 -0.7297 1.442 ...
#  $ dist_to_coast_mi  : num  1.99 1.95 1.91 1.88 1.85 ...
#  $ elevation_ft      : num  5.99 6.8 6.4 4.93 5.21 ...
#  $ tmean_2024_C      : num  -4.19 -4.41 -3.48 -3.23 -2.93 ...
#  $ ppt_2024_mm       : num  5.5 6.07 4.75 3.47 2.77 ...
#  $ det_freq_log      : num  -1.1 1.75 1.19 0.38 1.32 ...
#  $ dominant_eco_group: Factor w/ 5 levels "1","2","3","4",..: 3 3 3 3 3 3 3 3 3 3 ...
#  $ n_checklists      : num  1 11 180 20 10 2 35 5 15 91 ...

# %%
mod_add_pwo_logy_std = lm(det_freq_log ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                     dist_to_coast_mi + elevation_ft + dominant_eco_group +
                     tmean_2024_C + ppt_2024_mm,
                     data = ebird_features_df_pwo_logy_std, weight = n_checklists)
summary(mod_add_pwo_logy_std)
# Out:
# Call:
# lm(formula = det_freq_log ~ mean_num_observers + mean_start_time_hr +
#     med_duration + mean_dist_km + dist_to_coast_mi + elevation_ft +
#     dominant_eco_group + tmean_2024_C + ppt_2024_mm, data = ebird_features_df_pwo_logy_std,
#     weights = n_checklists)
#
# Weighted Residuals:
#      Min       1Q   Median       3Q      Max
# -28.5420  -1.7984  -0.3545   2.1007  19.2291
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)          0.04433    0.12231   0.362 0.717145
# mean_num_observers  -0.03749    0.04814  -0.779 0.436387
# mean_start_time_hr  -0.13244    0.03868  -3.424 0.000653 ***
# med_duration         0.19470    0.03170   6.142 1.37e-09 ***
# mean_dist_km         0.37270    0.03540  10.528  < 2e-16 ***
# dist_to_coast_mi     0.11248    0.04809   2.339 0.019618 *
# elevation_ft         0.12688    0.05673   2.236 0.025635 *
# dominant_eco_group2 -0.30244    0.12825  -2.358 0.018639 *
# ...

# %%
plot(resid(mod_add_pwo_logy_std) ~ fitted(mod_add_pwo_logy_std))
bptest(mod_add_pwo_logy_std)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod_add_pwo_logy_std
# BP = 54099, df = 12, p-value < 2.2e-16
# plot without title

# %% [markdown]
# ### future ref

# %%
library(MASS)
mod_add_pwo_shift = lm((det_freq + 0.1) ~ mean_num_observers + mean_start_time_hr + med_duration + mean_dist_km +
                     dist_to_coast_mi + elevation_ft + dominant_eco_group +
                     tmean_2024_C + ppt_2024_mm,
                     data = ebird_features_df_pwo, weight = n_checklists)
boxcox(mod_add_pwo_shift)
# Out:
# plot without title
